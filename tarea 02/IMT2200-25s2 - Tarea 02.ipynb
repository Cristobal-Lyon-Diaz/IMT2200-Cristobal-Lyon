# %% [markdown]
# # <img style="float: left; padding-right: 20px; width: 200px" src="https://raw.githubusercontent.com/raxlab/imt2200-data/main/media/logo.jpg">  IMT 2200 - Introducción a Ciencia de Datos
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>

# %% [markdown]
# # <h1><center>Tarea 02: Extracción y Transformación de Datos </center></h1>
#
# **Fecha de Entrega:** 25 de septiembre de 2025, a las 23:59.
#
# **Fecha de publicación**: 2 de septiembre de 2025.
#
# **Formato de entrega:** Notebook ejecutado y comentado (`.ipynb`) en el módulo de Tarea 02 habilitado en Canvas.

# %% [markdown]
# ## Instrucciones
#
# - Esta Tarea debe desarrollarse de manera totalmente *individual*, de acuerdo a lo establecido en la sección de Integridad Académica en el programa del curso.
# - La Tarea debe ser desarrollada en lenguaje de programación Python y la entrega en formato Jupyter Notebook.
# - El desarrollo del Notebook debe ser claro y ordenado, incluyendo anotaciones (markdown) y comentarios que permitan seguir fácilmente el código y los pasos implementados a los correctores, y siguiendo buenas prácticas de programación. La presentación y claridad del notebook y código forman parte de la evaluación de la tarea.
# - Notebook **autocontenible** que:
#    - Ejecute sin errores todas las celdas.
#   - Contenga tanto el código como los comentarios y explicaciones necesarias.
#   - Incluya visualizaciones claras y correctamente etiquetadas.
# - No se aceptarán notebooks con celdas rotas o que dependan de rutas externas no indicadas en la tarea.
#
# - Deben hacer sus consultas y comentarios sobre la Tarea a través del canal de Tareas en el Foro del curso en Canvas.

# %% [markdown]
# ## 1. Objetivos
#
# - Aplicar los conceptos iniciales de manejo de datos y análisis exploratorio vistos en clases.
# - Practicar la lectura, limpieza y manipulación de datos en Python.
# - Desarrollar habilidades para visualizar y describir patrones y tendencias en conjuntos de datos reales.
# - Fomentar la capacidad de comunicar resultados de forma clara y fundamentada.
#
# ### 1.1 Objetivo educacional
#
# Esta Tarea tiene como objetivo que los estudiantes desarrollen la capacidad de manejar algunas de las librerías centrales para el desarrollo de Ciencia de Datos, con foco en la lectura y exploración de datos.
#
# Para los ejercicios a continuación, usted deberá leer, inspeccionar, manipular y graficar conjuntos de datos en distintos formatos, de manera de responder las preguntas de cada parte de la Tarea.
#
# ### 1.2 Pregunta de ciencia de datos
#
# Para esta tarea, queremos comprender y visualizar la distribución de aves migratorias en el territorio chileno. Específicamente, queremos entender las diferencias entre las migraciones de 2 especies en particular, el run-run y la dormilona tontita, a partir de los avistamientos registrados en eBird durante un periodo de 3 años y medio.
#
# ### 1.3 Recomendaciones
# - Utiliza las librerías sugeridas en el notebook o justifica brevemente si incorporas otras.
# - Revisa que todas las celdas se ejecuten en orden, desde el inicio, sin errores.
# - Comenta tu código para explicar qué hace cada sección relevante.
# - Asegúrate de que las visualizaciones sean fáciles de interpretar y tengan títulos y etiquetas adecuados.

# %% [markdown]
# ### 1.4 Ejemplo de visualización
#
# Esta tarea se enfoca en datos de aves. Para complementarla, les compartimos la siguiente página web, llamada "Bird Migration Explorer" que les permite visualizar, de una forma novedosa e interesante, las rutas de migración de aves en las Americas. Visiten la página para que vean cómo se puede visualizar datos de una manera interesante y novedosa, que podría ustedes usar en el futuro para sus proyectos.

# %%
from IPython.display import IFrame
IFrame("https://explorer.audubon.org/home?layersPanel=expand", width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="https://explorer.audubon.org/home?layersPanel=expand"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 2. Datos
#
# Los datos a utilizar provienen de la plataforma **[eBird](https://ebird.org/)**, una aplicación desarrollada por The Cornell Lab of Ornithology que permite a sus usuarios registrar y compartir avistamientos de aves en todo el mundo. La plataforma dispone de una API mediante la cual se pueden realizar consultas sobre avistamientos de aves recientes e históricos, especies según región, taxonomía, entre otros.
#
# ### 2.1 Acceso a la API
#
# Muchas API pueden utilizarse solo mediante el uso de una clave única, o "API key". Para conseguir una API key en eBird, primero debe ser usuario de la plataforma. Puede crear una cuenta aquí: https://secure.birds.cornell.edu/identity/account/create
#
#
# Con una cuenta ya creada, puede ingresar a https://ebird.org/api/keygen para generar su llave. Debe llenar un formulario de solicitud al pedir su llave. Como sugerencia, puede llenar los campos con la siguiente información:
#
# * **Organización:** Pontificia Universidad Católica de Chile
# * **Título del Proyecto:** Tarea IMT2200 Introducción a Ciencia de Datos
# * **Descripción:** "Uso educativo para exploración y análisis de distribución de aves migratorias en Chile."
# * **Tipo de Proyecto:** Academic/Student
# * **Casos de uso:** Materiales educativos y artíticos (...)
#
# Debería recibir su llave inmediatamente después de enviar su solicitud. Como recomendación, puede revisar la documentación de la API en el siguiente link: https://documenter.getpostman.com/view/664302/S1ENwy59#intro
#
# #### 2.2 Mapoteca de BCN
#
# Para esta tarea queremos visualizar el movimiento de aves a lo largo de nuestro país. Para ello, también necesitaremos manejar datos geoespaciales: específicamente, trabajaremos con un mapa vectorial de Chile disponible en la página web de la Biblioteca del Congreso Nacional: https://www.bcn.cl/siit/mapas_vectoriales/index_html
#
# Descargue el archivo `.zip` para las **Divisiones regionales** y descomprímalo. Dentro de esta carpeta, habrá un archivo llamado `Regional.shp`, que utilizaremos con `geopandas` para graficar nuestro mapa de Chile.

# %% [markdown]
# ### 2.3 Librerías
#
# Para esta tarea recomendamos al menos usar las librerías indicadas en la siguiente celda del Notebook. Puede agregar otras si lo estima conveniente para responder de mejor forma las preguntas de la Tarea.

# %%
import requests
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# ## 3. Desarrollo
#
# Para cada una de las siguientes preguntas o actividades incluya una o más celdas de código y Markdown con las respuestas o comentarios necesarios para contestar la pregunta o lograr la actividad. Agregue sus celdas a continuación de cada pregunta para que el Notebook quede ordenado.
#
# En el caso de gráficos, figuras o tablas, asegúrese que todas tengan título, etiquetas en los ejes o haya claridad de los contenidos.
#
# ### 3.1 Extracción de datos (1.5 puntos)
#
# **(1 pto)** Vamos a crear nuestra base de datos con los avistamientos registrados en eBird dentro de Chile desde 2022 hasta 2025. Revise la documentación de la API y averigue cómo extraer los avistamientos de un día. Luego extraiga los avistamientos para todos los días desde el **1 de enero de 2022 hasta el 31 de julio de 2025.** Cuando haya logrado extraer todos los datos, guárdelos en un archivo CSV o parquet.
#
# Responda:
#
# **a) (0.2 pts)** ¿Cuántos avistamientos tiene su dataset?
#
# **b) (0.3 pts)** Obtenga la cantidad de veces que se repite cada especie en su dataset y ordénelas de mayor a menor. ¿Qué pasa con la cantidad de avistamientos según especie? ¿Por qué?
#
# **Recomendaciones:**
# * Puede usar la librería `datetime` para generar fechas: cree una lista con todas las fechas e itere sobre esta lista para hacer los llamados a la API.
# * **Pruebe primero con uno o dos días** para verificar el funcionamiento de su código y de la API.
# * Inspeccione la forma en la que vienen los datos.
# * Vaya guardando los datos extraídos en archivos (CSV o parquet), de modo que no tenga que repetir los llamados en caso de algún error.
#
# **Hint**: Los códigos regionales chilenos para la API son los siguientes,
# * `regionCode = CL`
# * `sppLocale = es_CL` (para obtener nombres chilenos de las aves)

# %% [markdown]
# Primero verificamos con un solo die que todo este correcto

# %%
regionCode = "CL"
y = "2022"
m = "1"
d = "1"

url = f"https://api.ebird.org/v2/data/obs/{regionCode}/historic/{y}/{m}/{d}"
headers = {
    'X-eBirdApiToken':'idff0s6in775'
}

respuesta = requests.get(url, headers=headers)
respuesta.json()
# Out:
# [{'speciesCode': 'soulap1',
#   'comName': 'Southern Lapwing',
#   'sciName': 'Vanellus chilensis',
#   'locId': 'L10140471',
#   'locName': 'Villa Parque Austral, Osorno, Región de los Lagos, CL (-40.586, -73.113)',
#   'obsDt': '2022-01-01 23:41',
#   'howMany': 3,
#   'lat': -40.585844,
#   'lng': -73.1131572,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99916680'},
#  {'speciesCode': 'bkfibi1',
#   'comName': 'Black-faced Ibis',
#   'sciName': 'Theristicus melanopis',
#   'locId': 'L7988120',
#   'locName': 'Leñadura, Nuestra casa',
#   'obsDt': '2022-01-01 22:18',
#   'howMany': 4,
#   'lat': -53.2145727,
#   'lng': -70.9476647,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100024876'},
#  {'speciesCode': 'grhowl2',
#   'comName': 'Lesser Horned Owl',
#   'sciName': 'Bubo magellanicus',
#   'locId': 'L7988120',
#   'locName': 'Leñadura, Nuestra casa',
#   'obsDt': '2022-01-01 22:18',
#   'howMany': 1,
#   'lat': -53.2145727,
#   'lng': -70.9476647,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100024876'},
#  {'speciesCode': 'austhr1',
#   'comName': 'Austral Thrush',
#   'sciName': 'Turdus falcklandii',
#   'locId': 'L7988120',
#   'locName': 'Leñadura, Nuestra casa',
#   'obsDt': '2022-01-01 22:18',
#   'howMany': 1,
#   'lat': -53.2145727,
#   'lng': -70.9476647,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100024876'},
#  {'speciesCode': 'rucspa1',
#   'comName': 'Rufous-collared Sparrow',
#   'sciName': 'Zonotrichia capensis',
#   'locId': 'L7988120',
#   'locName': 'Leñadura, Nuestra casa',
#   'obsDt': '2022-01-01 22:18',
#   'howMany': 2,
#   'lat': -53.2145727,
#   'lng': -70.9476647,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100024876'},
#  {'speciesCode': 'aupowl1',
#   'comName': 'Austral Pygmy-Owl',
#   'sciName': 'Glaucidium nana',
#   'locId': 'L17286565',
#   'locName': '2065 Tucapel, La Pintana, Región Metropolitana, CL (-33.589, -70.648)',
#   'obsDt': '2022-01-01 21:25',
#   'howMany': 1,
#   'lat': -33.5887633,
#   'lng': -70.6475923,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99884664'},
#  {'speciesCode': 'burpar',
#   'comName': 'Burrowing Parakeet',
#   'sciName': 'Cyanoliseus patagonus',
#   'locId': 'L9439970',
#   'locName': 'Laguna Desagüe El Colorado',
#   'obsDt': '2022-01-01 21:18',
#   'howMany': 50,
#   'lat': -35.6490013,
#   'lng': -71.2784384,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S101402782'},
#  {'speciesCode': 'redsho1',
#   'comName': 'Red Shoveler',
#   'sciName': 'Spatula platalea',
#   'locId': 'L1819549',
#   'locName': 'SN Humedales de Tongoy--Salinas Chicas',
#   'obsDt': '2022-01-01 21:12',
#   'howMany': 1,
#   'lat': -30.2828485,
#   'lng': -71.5062434,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883707'},
#  {'speciesCode': 'regcoo1',
#   'comName': 'Red-gartered Coot',
#   'sciName': 'Fulica armillata',
#   'locId': 'L1819549',
#   'locName': 'SN Humedales de Tongoy--Salinas Chicas',
#   'obsDt': '2022-01-01 21:12',
#   'howMany': 10,
#   'lat': -30.2828485,
#   'lng': -71.5062434,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883707'},
#  {'speciesCode': 'ameoys',
#   'comName': 'American Oystercatcher',
#   'sciName': 'Haematopus palliatus',
#   'locId': 'L1819549',
#   'locName': 'SN Humedales de Tongoy--Salinas Chicas',
#   'obsDt': '2022-01-01 21:12',
#   'howMany': 7,
#   'lat': -30.2828485,
#   'lng': -71.5062434,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883707'},
#  {'speciesCode': 'colplo1',
#   'comName': 'Collared Plover',
#   'sciName': 'Anarhynchus collaris',
#   'locId': 'L1819549',
#   'locName': 'SN Humedales de Tongoy--Salinas Chicas',
#   'obsDt': '2022-01-01 21:12',
#   'howMany': 20,
#   'lat': -30.2828485,
#   'lng': -71.5062434,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883707'},
#  {'speciesCode': 'whimbr',
#   'comName': 'Whimbrel',
#   'sciName': 'Numenius phaeopus',
#   'locId': 'L1819549',
#   'locName': 'SN Humedales de Tongoy--Salinas Chicas',
#   'obsDt': '2022-01-01 21:12',
#   'howMany': 2,
#   'lat': -30.2828485,
#   'lng': -71.5062434,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883707'},
#  {'speciesCode': 'kelgul',
#   'comName': 'Kelp Gull',
#   'sciName': 'Larus dominicanus',
#   'locId': 'L1819549',
#   'locName': 'SN Humedales de Tongoy--Salinas Chicas',
#   'obsDt': '2022-01-01 21:12',
#   'howMany': 23,
#   'lat': -30.2828485,
#   'lng': -71.5062434,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883707'},
#  {'speciesCode': 'eardov1',
#   'comName': 'Eared Dove',
#   'sciName': 'Zenaida auriculata',
#   'locId': 'L11298794',
#   'locName': 'Plaza Alcaldesa',
#   'obsDt': '2022-01-01 21:03',
#   'howMany': 5,
#   'lat': -33.5656608,
#   'lng': -70.5891088,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883447'},
#  {'speciesCode': 'chicar1',
#   'comName': 'Chimango Caracara',
#   'sciName': 'Daptrius chimango',
#   'locId': 'L11298794',
#   'locName': 'Plaza Alcaldesa',
#   'obsDt': '2022-01-01 21:03',
#   'howMany': 2,
#   'lat': -33.5656608,
#   'lng': -70.5891088,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883447'},
#  {'speciesCode': 'monpar',
#   'comName': 'Monk Parakeet',
#   'sciName': 'Myiopsitta monachus',
#   'locId': 'L11298794',
#   'locName': 'Plaza Alcaldesa',
#   'obsDt': '2022-01-01 21:03',
#   'howMany': 12,
#   'lat': -33.5656608,
#   'lng': -70.5891088,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883447',
#   'exoticCategory': 'N'},
#  {'speciesCode': 'pmtspi1',
#   'comName': 'Plain-mantled Tit-Spinetail',
#   'sciName': 'Leptasthenura aegithaloides',
#   'locId': 'L11298794',
#   'locName': 'Plaza Alcaldesa',
#   'obsDt': '2022-01-01 21:03',
#   'howMany': 1,
#   'lat': -33.5656608,
#   'lng': -70.5891088,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883447'},
#  {'speciesCode': 'whcela1',
#   'comName': 'White-crested Elaenia',
#   'sciName': 'Elaenia albiceps',
#   'locId': 'L11298794',
#   'locName': 'Plaza Alcaldesa',
#   'obsDt': '2022-01-01 21:03',
#   'howMany': 1,
#   'lat': -33.5656608,
#   'lng': -70.5891088,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883447'},
#  {'speciesCode': 'houwre4',
#   'comName': 'Southern House Wren',
#   'sciName': 'Troglodytes musculus',
#   'locId': 'L11298794',
#   'locName': 'Plaza Alcaldesa',
#   'obsDt': '2022-01-01 21:03',
#   'howMany': 1,
#   'lat': -33.5656608,
#   'lng': -70.5891088,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99883447'},
#  {'speciesCode': 'bawswa1',
#   'comName': 'Blue-and-white Swallow',
#   'sciName': 'Pygochelidon cyanoleuca',
#   'locId': 'L10181452',
#   'locName': 'Parque Tobalaba',
#   'obsDt': '2022-01-01 20:48',
#   'howMany': 1,
#   'lat': -33.4785655,
#   'lng': -70.5528538,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99881440'},
#  {'speciesCode': 'shicow',
#   'comName': 'Shiny Cowbird',
#   'sciName': 'Molothrus bonariensis',
#   'locId': 'L10181452',
#   'locName': 'Parque Tobalaba',
#   'obsDt': '2022-01-01 20:48',
#   'howMany': 1,
#   'lat': -33.4785655,
#   'lng': -70.5528538,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99881440'},
#  {'speciesCode': 'chiwig1',
#   'comName': 'Chiloe Wigeon',
#   'sciName': 'Mareca sibilatrix',
#   'locId': 'L5138046',
#   'locName': 'PN Patagonia--Valle Aviles',
#   'obsDt': '2022-01-01 20:36',
#   'lat': -47.0524641,
#   'lng': -72.2000456,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S129953334'},
#  {'speciesCode': 'andduc1',
#   'comName': 'Andean Duck',
#   'sciName': 'Oxyura ferruginea',
#   'locId': 'L5138046',
#   'locName': 'PN Patagonia--Valle Aviles',
#   'obsDt': '2022-01-01 20:36',
#   'lat': -47.0524641,
#   'lng': -72.2000456,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S129953334'},
#  {'speciesCode': 'strwoo6',
#   'comName': 'Striped Woodpecker',
#   'sciName': 'Dryobates lignarius',
#   'locId': 'L5138046',
#   'locName': 'PN Patagonia--Valle Aviles',
#   'obsDt': '2022-01-01 20:36',
#   'howMany': 1,
#   'lat': -47.0524641,
#   'lng': -72.2000456,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S129953334'},
#  {'speciesCode': 'y00678',
#   'comName': 'Crested Caracara',
#   'sciName': 'Caracara plancus',
#   'locId': 'L5138046',
#   'locName': 'PN Patagonia--Valle Aviles',
#   'obsDt': '2022-01-01 20:36',
#   'lat': -47.0524641,
#   'lng': -72.2000456,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S129953334'},
#  {'speciesCode': 'thtray1',
#   'comName': 'Thorn-tailed Rayadito',
#   'sciName': 'Aphrastura spinicauda',
#   'locId': 'L5138046',
#   'locName': 'PN Patagonia--Valle Aviles',
#   'obsDt': '2022-01-01 20:36',
#   'lat': -47.0524641,
#   'lng': -72.2000456,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S129953334'},
#  {'speciesCode': 'pasfin1',
#   'comName': 'Patagonian Sierra Finch',
#   'sciName': 'Phrygilus patagonicus',
#   'locId': 'L5138046',
#   'locName': 'PN Patagonia--Valle Aviles',
#   'obsDt': '2022-01-01 20:36',
#   'lat': -47.0524641,
#   'lng': -72.2000456,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S129953334'},
#  {'speciesCode': 'cosswa1',
#   'comName': 'Coscoroba Swan',
#   'sciName': 'Coscoroba coscoroba',
#   'locId': 'L3661191',
#   'locName': 'Estero de Topocalma--Desembocadura',
#   'obsDt': '2022-01-01 20:24',
#   'howMany': 23,
#   'lat': -34.1290711,
#   'lng': -71.9859839,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99880476'},
#  {'speciesCode': 'brhgul2',
#   'comName': 'Brown-hooded Gull',
#   'sciName': 'Chroicocephalus maculipennis',
#   'locId': 'L3661191',
#   'locName': 'Estero de Topocalma--Desembocadura',
#   'obsDt': '2022-01-01 20:24',
#   'howMany': 70,
#   'lat': -34.1290711,
#   'lng': -71.9859839,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99880476'},
#  {'speciesCode': 'giahum1',
#   'comName': 'Giant Hummingbird',
#   'sciName': 'Patagona gigas',
#   'locId': 'L13018067',
#   'locName': 'Pasaje Los Nardos 1976, Olmué CL-Valparaíso -32.99747, -71.18887',
#   'obsDt': '2022-01-01 20:12',
#   'howMany': 1,
#   'lat': -32.997473,
#   'lng': -71.188874,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99879064'},
#  {'speciesCode': 'rutpla1',
#   'comName': 'Rufous-tailed Plantcutter',
#   'sciName': 'Phytotoma rara',
#   'locId': 'L13018067',
#   'locName': 'Pasaje Los Nardos 1976, Olmué CL-Valparaíso -32.99747, -71.18887',
#   'obsDt': '2022-01-01 20:12',
#   'howMany': 1,
#   'lat': -32.997473,
#   'lng': -71.188874,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99879064'},
#  {'speciesCode': 'chimoc1',
#   'comName': 'Chilean Mockingbird',
#   'sciName': 'Mimus thenca',
#   'locId': 'L13018067',
#   'locName': 'Pasaje Los Nardos 1976, Olmué CL-Valparaíso -32.99747, -71.18887',
#   'obsDt': '2022-01-01 20:12',
#   'howMany': 1,
#   'lat': -32.997473,
#   'lng': -71.188874,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99879064'},
#  {'speciesCode': 'ausbla1',
#   'comName': 'Austral Blackbird',
#   'sciName': 'Curaeus curaeus',
#   'locId': 'L13018067',
#   'locName': 'Pasaje Los Nardos 1976, Olmué CL-Valparaíso -32.99747, -71.18887',
#   'obsDt': '2022-01-01 20:12',
#   'howMany': 15,
#   'lat': -32.997473,
#   'lng': -71.188874,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99879064'},
#  {'speciesCode': 'chipig2',
#   'comName': 'Chilean Pigeon',
#   'sciName': 'Patagioenas araucana',
#   'locId': 'L17285700',
#   'locName': 'Mirador Laguna Verde',
#   'obsDt': '2022-01-01 20:10',
#   'howMany': 3,
#   'lat': -33.0823921,
#   'lng': -71.6629017,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99879294'},
#  {'speciesCode': 'houspa',
#   'comName': 'House Sparrow',
#   'sciName': 'Passer domesticus',
#   'locId': 'L6642998',
#   'locName': 'Barrio LLaima; Temuco',
#   'obsDt': '2022-01-01 19:51',
#   'howMany': 1,
#   'lat': -38.7350935,
#   'lng': -72.6221453,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99876103',
#   'exoticCategory': 'N'},
#  {'speciesCode': 'wepdov1',
#   'comName': 'West Peruvian Dove',
#   'sciName': 'Zenaida meloda',
#   'locId': 'L2773246',
#   'locName': 'Mi Jardín',
#   'obsDt': '2022-01-01 19:49',
#   'howMany': 2,
#   'lat': -31.6340747,
#   'lng': -71.1660148,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99875968'},
#  {'speciesCode': 'codfin1',
#   'comName': 'Diuca Finch',
#   'sciName': 'Diuca diuca',
#   'locId': 'L2773246',
#   'locName': 'Mi Jardín',
#   'obsDt': '2022-01-01 19:49',
#   'howMany': 2,
#   'lat': -31.6340747,
#   'lng': -71.1660148,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99875968'},
#  {'speciesCode': 'blnswa2',
#   'comName': 'Black-necked Swan',
#   'sciName': 'Cygnus melancoryphus',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 27,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'flistd1',
#   'comName': 'Flightless Steamer-Duck',
#   'sciName': 'Tachyeres pteneres',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 10,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'yebtea1',
#   'comName': 'Yellow-billed Teal',
#   'sciName': 'Anas flavirostris',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 4,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'greyel',
#   'comName': 'Greater Yellowlegs',
#   'sciName': 'Tringa melanoleuca',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 2,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'fragul',
#   'comName': "Franklin's Gull",
#   'sciName': 'Leucophaeus pipixcan',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 1,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'soater1',
#   'comName': 'South American Tern',
#   'sciName': 'Sterna hirundinacea',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 2,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'silgre1',
#   'comName': 'Silvery Grebe',
#   'sciName': 'Podiceps occipitalis',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 46,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'neocor',
#   'comName': 'Neotropic Cormorant',
#   'sciName': 'Nannopterum brasilianum',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 1,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'bcnher',
#   'comName': 'Black-crowned Night Heron',
#   'sciName': 'Nycticorax nycticorax',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 1,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'dabcin1',
#   'comName': 'Dark-bellied Cinclodes',
#   'sciName': 'Cinclodes patagonicus',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 2,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'chiswa1',
#   'comName': 'Chilean Swallow',
#   'sciName': 'Tachycineta leucopyga',
#   'locId': 'L15391011',
#   'locName': 'Cruce Ruta 5 (Coinco) - Candelaria - Oqueldán, Quellón CL-Los Lagos -43.06298, -73.56207',
#   'obsDt': '2022-01-01 19:43',
#   'howMany': 2,
#   'lat': -43.062983,
#   'lng': -73.562065,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99880846'},
#  {'speciesCode': 'cinhar1',
#   'comName': 'Cinereous Harrier',
#   'sciName': 'Circus cinereus',
#   'locId': 'L17285264',
#   'locName': '1711270, La Serena CL-Regione di Coquimbo -29.89914, -71.27097',
#   'obsDt': '2022-01-01 19:35',
#   'howMany': 3,
#   'lat': -29.899139,
#   'lng': -71.270972,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99876937'},
#  {'speciesCode': 'spetyr1',
#   'comName': 'Spectacled Tyrant',
#   'sciName': 'Hymenops perspicillatus',
#   'locId': 'L17285264',
#   'locName': '1711270, La Serena CL-Regione di Coquimbo -29.89914, -71.27097',
#   'obsDt': '2022-01-01 19:35',
#   'howMany': 1,
#   'lat': -29.899139,
#   'lng': -71.270972,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99876937'},
#  {'speciesCode': 'rocpig',
#   'comName': 'Rock Pigeon',
#   'sciName': 'Columba livia',
#   'locId': 'L13417914',
#   'locName': 'Plaza el Corregidor, Villa Chuquicamata',
#   'obsDt': '2022-01-01 19:32',
#   'howMany': 6,
#   'lat': -23.6400814,
#   'lng': -70.395508,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99875138',
#   'exoticCategory': 'N'},
#  {'speciesCode': 'oashum1',
#   'comName': 'Oasis Hummingbird',
#   'sciName': 'Rhodopis vesper',
#   'locId': 'L13417914',
#   'locName': 'Plaza el Corregidor, Villa Chuquicamata',
#   'obsDt': '2022-01-01 19:32',
#   'howMany': 1,
#   'lat': -23.6400814,
#   'lng': -70.395508,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99875138'},
#  {'speciesCode': 'fiediu1',
#   'comName': 'Fire-eyed Diucon',
#   'sciName': 'Pyrope pyrope',
#   'locId': 'L10601056',
#   'locName': 'Lo Cañas (-33.5207, -70.5435)',
#   'obsDt': '2022-01-01 19:30',
#   'howMany': 1,
#   'lat': -33.5207,
#   'lng': -70.5435,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99984147'},
#  {'speciesCode': 'pigdov1',
#   'comName': 'Picui Ground Dove',
#   'sciName': 'Columbina picui',
#   'locId': 'L968193',
#   'locName': 'Linares',
#   'obsDt': '2022-01-01 19:24',
#   'howMany': 1,
#   'lat': -35.8453911,
#   'lng': -71.5980399,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99881087'},
#  {'speciesCode': 'plurai1',
#   'comName': 'Plumbeous Rail',
#   'sciName': 'Pardirallus sanguinolentus',
#   'locId': 'L17285445',
#   'locName': '1930 Anibal Pinto, Concepción, Bío Bío, CL (-36.807, -73.059)',
#   'obsDt': '2022-01-01 19:23',
#   'howMany': 1,
#   'lat': -36.8066424,
#   'lng': -73.0594296,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99877905'},
#  {'speciesCode': 'whfibi',
#   'comName': 'White-faced Ibis',
#   'sciName': 'Plegadis chihi',
#   'locId': 'L17285445',
#   'locName': '1930 Anibal Pinto, Concepción, Bío Bío, CL (-36.807, -73.059)',
#   'obsDt': '2022-01-01 19:23',
#   'howMany': 2,
#   'lat': -36.8066424,
#   'lng': -73.0594296,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99877905'},
#  {'speciesCode': 'wrlrus1',
#   'comName': 'Wren-like Rushbird',
#   'sciName': 'Phleocryptes melanops',
#   'locId': 'L17285445',
#   'locName': '1930 Anibal Pinto, Concepción, Bío Bío, CL (-36.807, -73.059)',
#   'obsDt': '2022-01-01 19:23',
#   'howMany': 1,
#   'lat': -36.8066424,
#   'lng': -73.0594296,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99877905'},
#  {'speciesCode': 'mcrtyr1',
#   'comName': 'Many-colored Rush Tyrant',
#   'sciName': 'Tachuris rubrigastra',
#   'locId': 'L17285445',
#   'locName': '1930 Anibal Pinto, Concepción, Bío Bío, CL (-36.807, -73.059)',
#   'obsDt': '2022-01-01 19:23',
#   'howMany': 2,
#   'lat': -36.8066424,
#   'lng': -73.0594296,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99877905'},
#  {'speciesCode': 'yewbla2',
#   'comName': 'Yellow-winged Blackbird',
#   'sciName': 'Agelasticus thilius',
#   'locId': 'L17285445',
#   'locName': '1930 Anibal Pinto, Concepción, Bío Bío, CL (-36.807, -73.059)',
#   'obsDt': '2022-01-01 19:23',
#   'howMany': 5,
#   'lat': -36.8066424,
#   'lng': -73.0594296,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99877905'},
#  {'speciesCode': 'andcon1',
#   'comName': 'Andean Condor',
#   'sciName': 'Vultur gryphus',
#   'locId': 'L17357941',
#   'locName': 'Valle Rio Aviles PN Patagonia, Aysén, CL (-47,042, -72,181)',
#   'obsDt': '2022-01-01 19:22',
#   'howMany': 5,
#   'lat': -47.0418525,
#   'lng': -72.1813625,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100305122'},
#  {'speciesCode': 'auscan1',
#   'comName': 'Austral Canastero',
#   'sciName': 'Asthenes anthoides',
#   'locId': 'L17357941',
#   'locName': 'Valle Rio Aviles PN Patagonia, Aysén, CL (-47,042, -72,181)',
#   'obsDt': '2022-01-01 19:22',
#   'howMany': 6,
#   'lat': -47.0418525,
#   'lng': -72.1813625,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': True,
#   'subId': 'S100305122'},
#  {'speciesCode': 'corcan1',
#   'comName': 'Cordilleran Canastero',
#   'sciName': 'Asthenes modesta',
#   'locId': 'L17357941',
#   'locName': 'Valle Rio Aviles PN Patagonia, Aysén, CL (-47,042, -72,181)',
#   'obsDt': '2022-01-01 19:22',
#   'howMany': 3,
#   'lat': -47.0418525,
#   'lng': -72.1813625,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100305122'},
#  {'speciesCode': 'shbcan2',
#   'comName': 'Sharp-billed Canastero',
#   'sciName': 'Asthenes pyrrholeuca',
#   'locId': 'L17357941',
#   'locName': 'Valle Rio Aviles PN Patagonia, Aysén, CL (-47,042, -72,181)',
#   'obsDt': '2022-01-01 19:22',
#   'howMany': 1,
#   'lat': -47.0418525,
#   'lng': -72.1813625,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100305122'},
#  {'speciesCode': 'pifshe',
#   'comName': 'Pink-footed Shearwater',
#   'sciName': 'Ardenna creatopus',
#   'locId': 'L17253745',
#   'locName': 'View Buchupureo, Cobquecura, Bío Bío, CL (-36.08, -72.808)',
#   'obsDt': '2022-01-01 19:18',
#   'howMany': 80,
#   'lat': -36.0802958,
#   'lng': -72.808102,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99873454'},
#  {'speciesCode': 'sooshe',
#   'comName': 'Sooty Shearwater',
#   'sciName': 'Ardenna grisea',
#   'locId': 'L17253745',
#   'locName': 'View Buchupureo, Cobquecura, Bío Bío, CL (-36.08, -72.808)',
#   'obsDt': '2022-01-01 19:18',
#   'howMany': 120,
#   'lat': -36.0802958,
#   'lng': -72.808102,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99873454'},
#  {'speciesCode': 'relcor1',
#   'comName': 'Red-legged Cormorant',
#   'sciName': 'Poikilocarbo gaimardi',
#   'locId': 'L17253745',
#   'locName': 'View Buchupureo, Cobquecura, Bío Bío, CL (-36.08, -72.808)',
#   'obsDt': '2022-01-01 19:18',
#   'howMany': 40,
#   'lat': -36.0802958,
#   'lng': -72.808102,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99873454'},
#  {'speciesCode': 'guacor1',
#   'comName': 'Guanay Cormorant',
#   'sciName': 'Leucocarbo bougainvilliorum',
#   'locId': 'L17253745',
#   'locName': 'View Buchupureo, Cobquecura, Bío Bío, CL (-36.08, -72.808)',
#   'obsDt': '2022-01-01 19:18',
#   'howMany': 6,
#   'lat': -36.0802958,
#   'lng': -72.808102,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99873454'},
#  {'speciesCode': 'turvul',
#   'comName': 'Turkey Vulture',
#   'sciName': 'Cathartes aura',
#   'locId': 'L17253745',
#   'locName': 'View Buchupureo, Cobquecura, Bío Bío, CL (-36.08, -72.808)',
#   'obsDt': '2022-01-01 19:18',
#   'howMany': 8,
#   'lat': -36.0802958,
#   'lng': -72.808102,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99873454'},
#  {'speciesCode': 'gryfin1',
#   'comName': 'Grassland Yellow-Finch',
#   'sciName': 'Sicalis luteola',
#   'locId': 'L12225403',
#   'locName': '20 General Baquedano, Nueva Branau, Los Lagos, CL (-41.324, -73.07)',
#   'obsDt': '2022-01-01 19:11',
#   'howMany': 2,
#   'lat': -41.3243662,
#   'lng': -73.0704785,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99872376'},
#  {'speciesCode': 'yebpin1',
#   'comName': 'Yellow-billed Pintail',
#   'sciName': 'Anas georgica',
#   'locId': 'L1819585',
#   'locName': 'SN Humedales de Tongoy--Salinas Grande',
#   'obsDt': '2022-01-01 19:01',
#   'howMany': 3,
#   'lat': -30.2981285,
#   'lng': -71.537872,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99877373'},
#  {'speciesCode': 'refcoo1',
#   'comName': 'Red-fronted Coot',
#   'sciName': 'Fulica rufifrons',
#   'locId': 'L1819585',
#   'locName': 'SN Humedales de Tongoy--Salinas Grande',
#   'obsDt': '2022-01-01 19:01',
#   'howMany': 1,
#   'lat': -30.2981285,
#   'lng': -71.537872,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99877373'},
#  {'speciesCode': 'bknsti',
#   'comName': 'Black-necked Stilt',
#   'sciName': 'Himantopus mexicanus',
#   'locId': 'L1819585',
#   'locName': 'SN Humedales de Tongoy--Salinas Grande',
#   'obsDt': '2022-01-01 19:01',
#   'howMany': 2,
#   'lat': -30.2981285,
#   'lng': -71.537872,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99877373'},
#  {'speciesCode': 'greegr',
#   'comName': 'Great Egret',
#   'sciName': 'Ardea alba',
#   'locId': 'L1819585',
#   'locName': 'SN Humedales de Tongoy--Salinas Grande',
#   'obsDt': '2022-01-01 19:01',
#   'howMany': 1,
#   'lat': -30.2981285,
#   'lng': -71.537872,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99877373'},
#  {'speciesCode': 'ausneg1',
#   'comName': 'Austral Negrito',
#   'sciName': 'Lessonia rufa',
#   'locId': 'L1819585',
#   'locName': 'SN Humedales de Tongoy--Salinas Grande',
#   'obsDt': '2022-01-01 19:01',
#   'howMany': 2,
#   'lat': -30.2981285,
#   'lng': -71.537872,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99877373'},
#  {'speciesCode': 'whcpin',
#   'comName': 'White-cheeked Pintail',
#   'sciName': 'Anas bahamensis',
#   'locId': 'L13875547',
#   'locName': 'Humedales de La Capilla',
#   'obsDt': '2022-01-01 19:00',
#   'howMany': 3,
#   'lat': -34.4885075,
#   'lng': -70.9402959,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S116814692'},
#  {'speciesCode': 'rudtur',
#   'comName': 'Ruddy Turnstone',
#   'sciName': 'Arenaria interpres',
#   'locId': 'L4950100',
#   'locName': 'Parque de los Eventos',
#   'obsDt': '2022-01-01 19:00',
#   'howMany': 20,
#   'lat': -23.6288572,
#   'lng': -70.3969869,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99873576'},
#  {'speciesCode': 'surfbi',
#   'comName': 'Surfbird',
#   'sciName': 'Calidris virgata',
#   'locId': 'L4950100',
#   'locName': 'Parque de los Eventos',
#   'obsDt': '2022-01-01 19:00',
#   'howMany': 30,
#   'lat': -23.6288572,
#   'lng': -70.3969869,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99873576'},
#  {'speciesCode': 'grygul',
#   'comName': 'Gray Gull',
#   'sciName': 'Leucophaeus modestus',
#   'locId': 'L4950100',
#   'locName': 'Parque de los Eventos',
#   'obsDt': '2022-01-01 19:00',
#   'howMany': 10,
#   'lat': -23.6288572,
#   'lng': -70.3969869,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99873576'},
#  {'speciesCode': 'belgul',
#   'comName': "Belcher's Gull",
#   'sciName': 'Larus belcheri',
#   'locId': 'L4950100',
#   'locName': 'Parque de los Eventos',
#   'obsDt': '2022-01-01 19:00',
#   'howMany': 1,
#   'lat': -23.6288572,
#   'lng': -70.3969869,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99873576'},
#  {'speciesCode': 'perpel1',
#   'comName': 'Peruvian Pelican',
#   'sciName': 'Pelecanus thagus',
#   'locId': 'L4950100',
#   'locName': 'Parque de los Eventos',
#   'obsDt': '2022-01-01 19:00',
#   'howMany': 9,
#   'lat': -23.6288572,
#   'lng': -70.3969869,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99873576'},
#  {'speciesCode': 'whtkit',
#   'comName': 'White-tailed Kite',
#   'sciName': 'Elanus leucurus',
#   'locId': 'L17284049',
#   'locName': 'Río Imperial--Carahue',
#   'obsDt': '2022-01-01 18:47',
#   'howMany': 1,
#   'lat': -38.7147526,
#   'lng': -73.1713033,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99870207'},
#  {'speciesCode': 'lotmea1',
#   'comName': 'Long-tailed Meadowlark',
#   'sciName': 'Leistes loyca',
#   'locId': 'L17284149',
#   'locName': 'V-690, Los Muermos, Los Lagos, CL (-41.42, -73.417)',
#   'obsDt': '2022-01-01 18:47',
#   'howMany': 6,
#   'lat': -41.4203285,
#   'lng': -73.4167596,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99870795'},
#  {'speciesCode': 'gregre1',
#   'comName': 'Great Grebe',
#   'sciName': 'Podiceps major',
#   'locId': 'L17318000',
#   'locName': 'Llanada Grande - Segundo Corral, Cochamó CL-Los Lagos -41.94821, -71.89038',
#   'obsDt': '2022-01-01 18:33',
#   'howMany': 1,
#   'lat': -41.948206,
#   'lng': -71.890384,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100063592'},
#  {'speciesCode': 'chutap1',
#   'comName': 'Chucao Tapaculo',
#   'sciName': 'Scelorchilus rubecula',
#   'locId': 'L17318000',
#   'locName': 'Llanada Grande - Segundo Corral, Cochamó CL-Los Lagos -41.94821, -71.89038',
#   'obsDt': '2022-01-01 18:33',
#   'howMany': 1,
#   'lat': -41.948206,
#   'lng': -71.890384,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100063592'},
#  {'speciesCode': 'uplgoo1',
#   'comName': 'Upland Goose',
#   'sciName': 'Chloephaga picta',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 60,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'flystd1',
#   'comName': 'Flying Steamer-Duck',
#   'sciName': 'Tachyeres patachonicus',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 2,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'creduc1',
#   'comName': 'Crested Duck',
#   'sciName': 'Lophonetta specularioides',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 6,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'whwcoo1',
#   'comName': 'White-winged Coot',
#   'sciName': 'Fulica leucoptera',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 8,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'magoys1',
#   'comName': 'Magellanic Oystercatcher',
#   'sciName': 'Haematopus leucopodus',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 1,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'hudgod',
#   'comName': 'Hudsonian Godwit',
#   'sciName': 'Limosa haemastica',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 3,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'soasni3',
#   'comName': 'Magellanic Snipe',
#   'sciName': 'Gallinago magellanica',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 2,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'lesyel',
#   'comName': 'Lesser Yellowlegs',
#   'sciName': 'Tringa flavipes',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 8,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'baisan',
#   'comName': "Baird's Sandpiper",
#   'sciName': 'Calidris bairdii',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 30,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'whrsan',
#   'comName': 'White-rumped Sandpiper',
#   'sciName': 'Calidris fuscicollis',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 3,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'pecsan',
#   'comName': 'Pectoral Sandpiper',
#   'sciName': 'Calidris melanotos',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 1,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'dolgul2',
#   'comName': 'Dolphin Gull',
#   'sciName': 'Leucophaeus scoresbii',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 1,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'chifla1',
#   'comName': 'Chilean Flamingo',
#   'sciName': 'Phoenicopterus chilensis',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 18,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'whtgre3',
#   'comName': 'White-tufted Grebe',
#   'sciName': 'Rollandia rolland',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 1,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'buwcin1',
#   'comName': 'Buff-winged Cinclodes',
#   'sciName': 'Cinclodes fuscus',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 1,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'barswa',
#   'comName': 'Barn Swallow',
#   'sciName': 'Hirundo rustica',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 1,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'sedwre',
#   'comName': 'Grass Wren',
#   'sciName': 'Cistothorus platensis',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 2,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'corpip1',
#   'comName': 'Correndera Pipit',
#   'sciName': 'Anthus correndera',
#   'locId': 'L606243',
#   'locName': 'Humedal Tres Puentes',
#   'obsDt': '2022-01-01 18:30',
#   'howMany': 2,
#   'lat': -53.1162328,
#   'lng': -70.8813,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99892249'},
#  {'speciesCode': 'siltea1',
#   'comName': 'Silver Teal',
#   'sciName': 'Spatula versicolor',
#   'locId': 'L17283777',
#   'locName': 'S-36, Carahue, Araucanía, CL (-38.696, -73.292)',
#   'obsDt': '2022-01-01 18:16',
#   'howMany': 6,
#   'lat': -38.6956766,
#   'lng': -73.2919723,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99868650'},
#  {'speciesCode': 'cintea',
#   'comName': 'Cinnamon Teal',
#   'sciName': 'Spatula cyanoptera',
#   'locId': 'L17283777',
#   'locName': 'S-36, Carahue, Araucanía, CL (-38.696, -73.292)',
#   'obsDt': '2022-01-01 18:16',
#   'howMany': 5,
#   'lat': -38.6956766,
#   'lng': -73.2919723,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99868650'},
#  {'speciesCode': 'lakduc1',
#   'comName': 'Lake Duck',
#   'sciName': 'Oxyura vittata',
#   'locId': 'L17283777',
#   'locName': 'S-36, Carahue, Araucanía, CL (-38.696, -73.292)',
#   'obsDt': '2022-01-01 18:16',
#   'howMany': 1,
#   'lat': -38.6956766,
#   'lng': -73.2919723,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99868650'},
#  {'speciesCode': 'snoegr',
#   'comName': 'Snowy Egret',
#   'sciName': 'Egretta thula',
#   'locId': 'L17283777',
#   'locName': 'S-36, Carahue, Araucanía, CL (-38.696, -73.292)',
#   'obsDt': '2022-01-01 18:16',
#   'howMany': 1,
#   'lat': -38.6956766,
#   'lng': -73.2919723,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99868650'},
#  {'speciesCode': 'tuttyr1',
#   'comName': 'Tufted Tit-Tyrant',
#   'sciName': 'Anairetes parulus',
#   'locId': 'L2315910',
#   'locName': 'San José de Maipo',
#   'obsDt': '2022-01-01 18:15',
#   'howMany': 1,
#   'lat': -33.640337,
#   'lng': -70.3527895,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99926978'},
#  {'speciesCode': 'incter1',
#   'comName': 'Inca Tern',
#   'sciName': 'Larosterna inca',
#   'locId': 'L775567',
#   'locName': 'MN La Portada',
#   'obsDt': '2022-01-01 18:07',
#   'howMany': 50,
#   'lat': -23.5014628,
#   'lng': -70.4270715,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99867463'},
#  {'speciesCode': 'humpen1',
#   'comName': 'Humboldt Penguin',
#   'sciName': 'Spheniscus humboldti',
#   'locId': 'L775567',
#   'locName': 'MN La Portada',
#   'obsDt': '2022-01-01 18:07',
#   'howMany': 3,
#   'lat': -23.5014628,
#   'lng': -70.4270715,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99867463'},
#  {'speciesCode': 'perboo1',
#   'comName': 'Peruvian Booby',
#   'sciName': 'Sula variegata',
#   'locId': 'L775567',
#   'locName': 'MN La Portada',
#   'obsDt': '2022-01-01 18:07',
#   'howMany': 1000,
#   'lat': -23.5014628,
#   'lng': -70.4270715,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99867463'},
#  {'speciesCode': 'comter',
#   'comName': 'Common Tern',
#   'sciName': 'Sterna hirundo',
#   'locId': 'L17283688',
#   'locName': '2125 Brasilia, Arica, Arica y Parinacota, CL (-18.463, -70.306)',
#   'obsDt': '2022-01-01 17:50',
#   'howMany': 3,
#   'lat': -18.4628903,
#   'lng': -70.3061139,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100175919'},
#  {'speciesCode': 'blkvul',
#   'comName': 'Black Vulture',
#   'sciName': 'Coragyps atratus',
#   'locId': 'L5114227',
#   'locName': 'El Quisco--Quebrada las Petras',
#   'obsDt': '2022-01-01 17:49',
#   'howMany': 2,
#   'lat': -33.369826,
#   'lng': -71.693201,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100112656'},
#  {'speciesCode': 'bichaw4',
#   'comName': 'Chilean Hawk',
#   'sciName': 'Astur chilensis',
#   'locId': 'L5114227',
#   'locName': 'El Quisco--Quebrada las Petras',
#   'obsDt': '2022-01-01 17:49',
#   'howMany': 3,
#   'lat': -33.369826,
#   'lng': -71.693201,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S100112656'},
#  {'speciesCode': 'chifli1',
#   'comName': 'Chilean Flicker',
#   'sciName': 'Colaptes pitius',
#   'locId': 'L12044949',
#   'locName': 'Chaitén viejo',
#   'obsDt': '2022-01-01 17:41',
#   'howMany': 2,
#   'lat': -42.9476814,
#   'lng': -72.7307882,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99879088'},
#  {'speciesCode': 'gyfcin1',
#   'comName': 'Gray-flanked Cinclodes',
#   'sciName': 'Cinclodes oustaleti',
#   'locId': 'L12044949',
#   'locName': 'Chaitén viejo',
#   'obsDt': '2022-01-01 17:41',
#   'howMany': 1,
#   'lat': -42.9476814,
#   'lng': -72.7307882,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99879088'},
#  {'speciesCode': 'demwir1',
#   'comName': "Des Murs's Wiretail",
#   'sciName': 'Sylviorthorhynchus desmursii',
#   'locId': 'L12044949',
#   'locName': 'Chaitén viejo',
#   'obsDt': '2022-01-01 17:41',
#   'howMany': 1,
#   'lat': -42.9476814,
#   'lng': -72.7307882,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99879088'},
#  {'speciesCode': 'blcsis2',
#   'comName': 'Black-chinned Siskin',
#   'sciName': 'Spinus barbatus',
#   'locId': 'L12044949',
#   'locName': 'Chaitén viejo',
#   'obsDt': '2022-01-01 17:41',
#   'howMany': 3,
#   'lat': -42.9476814,
#   'lng': -72.7307882,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99879088'},
#  {'speciesCode': 'blaoys1',
#   'comName': 'Blackish Oystercatcher',
#   'sciName': 'Haematopus ater',
#   'locId': 'L17283322',
#   'locName': 'Playa El Salitre, Tocopilla',
#   'obsDt': '2022-01-01 17:40',
#   'howMany': 6,
#   'lat': -22.0895023,
#   'lng': -70.199037,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99866249'},
#  {'speciesCode': 'rebhaw2',
#   'comName': 'Variable Hawk',
#   'sciName': 'Geranoaetus polyosoma',
#   'locId': 'L807422',
#   'locName': 'Tranque Los Aromos',
#   'obsDt': '2022-01-01 17:40',
#   'howMany': 1,
#   'lat': -32.9710477,
#   'lng': -71.3701916,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99880745'},
#  {'speciesCode': 'seacin1',
#   'comName': 'Seaside Cinclodes',
#   'sciName': 'Cinclodes nigrofumosus',
#   'locId': 'L17283322',
#   'locName': 'Playa El Salitre, Tocopilla',
#   'obsDt': '2022-01-01 17:40',
#   'howMany': 1,
#   'lat': -22.0895023,
#   'lng': -70.199037,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99866249'},
#  {'speciesCode': 'calqua',
#   'comName': 'California Quail',
#   'sciName': 'Callipepla californica',
#   'locId': 'L10653544',
#   'locName': 'Peña Blanca',
#   'obsDt': '2022-01-01 17:30',
#   'howMany': 4,
#   'lat': -34.5194864,
#   'lng': -71.6985723,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100247926',
#   'exoticCategory': 'N'},
#  {'speciesCode': 'twbplo1',
#   'comName': 'Two-banded Plover',
#   'sciName': 'Anarhynchus falklandicus',
#   'locId': 'L17282971',
#   'locName': 'Porvenir - Bahía Chilota - Parcelas, Porvenir CL-Magallanes and Antartica Chilena -53.30755, -70.44369',
#   'obsDt': '2022-01-01 17:15',
#   'howMany': 2,
#   'lat': -53.307548,
#   'lng': -70.443687,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99864428'},
#  {'speciesCode': 'chisku1',
#   'comName': 'Chilean Skua',
#   'sciName': 'Stercorarius chilensis',
#   'locId': 'L17282971',
#   'locName': 'Porvenir - Bahía Chilota - Parcelas, Porvenir CL-Magallanes and Antartica Chilena -53.30755, -70.44369',
#   'obsDt': '2022-01-01 17:15',
#   'howMany': 4,
#   'lat': -53.307548,
#   'lng': -70.443687,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99864428'},
#  {'speciesCode': 'impcor1',
#   'comName': 'Imperial Cormorant',
#   'sciName': 'Leucocarbo atriceps',
#   'locId': 'L17282971',
#   'locName': 'Porvenir - Bahía Chilota - Parcelas, Porvenir CL-Magallanes and Antartica Chilena -53.30755, -70.44369',
#   'obsDt': '2022-01-01 17:15',
#   'howMany': 4,
#   'lat': -53.307548,
#   'lng': -70.443687,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99864428'},
#  {'speciesCode': 'blkski',
#   'comName': 'Black Skimmer',
#   'sciName': 'Rynchops niger',
#   'locId': 'L509064',
#   'locName': 'SN Laguna Conchalí',
#   'obsDt': '2022-01-01 17:04',
#   'lat': -31.8780678,
#   'lng': -71.4966631,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100006880'},
#  {'speciesCode': 'gresht1',
#   'comName': 'Great Shrike-Tyrant',
#   'sciName': 'Agriornis lividus',
#   'locId': 'L509064',
#   'locName': 'SN Laguna Conchalí',
#   'obsDt': '2022-01-01 17:04',
#   'howMany': 1,
#   'lat': -31.8780678,
#   'lng': -71.4966631,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100006880'},
#  {'speciesCode': 'gyhsif1',
#   'comName': 'Gray-hooded Sierra Finch',
#   'sciName': 'Phrygilus gayi',
#   'locId': 'L509064',
#   'locName': 'SN Laguna Conchalí',
#   'obsDt': '2022-01-01 17:04',
#   'howMany': 1,
#   'lat': -31.8780678,
#   'lng': -71.4966631,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100006880'},
#  {'speciesCode': 'cibgrt1',
#   'comName': 'Cinnamon-bellied Ground-Tyrant',
#   'sciName': 'Muscisaxicola capistratus',
#   'locId': 'L572718',
#   'locName': 'MN Laguna de los Cisnes',
#   'obsDt': '2022-01-01 16:06',
#   'howMany': 1,
#   'lat': -53.2465985,
#   'lng': -70.3735364,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99864490'},
#  {'speciesCode': 'amekes',
#   'comName': 'American Kestrel',
#   'sciName': 'Falco sparverius',
#   'locId': 'L10581099',
#   'locName': 'Calle Panamá',
#   'obsDt': '2022-01-01 15:42',
#   'howMany': 1,
#   'lat': -33.5358966,
#   'lng': -70.5796383,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99926452'},
#  {'speciesCode': 'bkbplo',
#   'comName': 'Black-bellied Plover',
#   'sciName': 'Pluvialis squatarola',
#   'locId': 'L750209',
#   'locName': 'Puerto Aldea',
#   'obsDt': '2022-01-01 15:38',
#   'howMany': 7,
#   'lat': -30.2920896,
#   'lng': -71.6084683,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100001455'},
#  {'speciesCode': 'sander',
#   'comName': 'Sanderling',
#   'sciName': 'Calidris alba',
#   'locId': 'L750209',
#   'locName': 'Puerto Aldea',
#   'obsDt': '2022-01-01 15:38',
#   'howMany': 300,
#   'lat': -30.2920896,
#   'lng': -71.6084683,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100001455'},
#  {'speciesCode': 'commin1',
#   'comName': 'Common Miner',
#   'sciName': 'Geositta cunicularia',
#   'locId': 'L750209',
#   'locName': 'Puerto Aldea',
#   'obsDt': '2022-01-01 15:38',
#   'howMany': 1,
#   'lat': -30.2920896,
#   'lng': -71.6084683,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100001455'},
#  {'speciesCode': 'cocher1',
#   'comName': 'Cocoi Heron',
#   'sciName': 'Ardea cocoi',
#   'locId': 'L13853229',
#   'locName': 'Estero El Sauce--Puente peatonal',
#   'obsDt': '2022-01-01 15:35',
#   'howMany': 1,
# ...
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99949872'},
#  {'speciesCode': 'angpet1',
#   'comName': 'Southern Giant-Petrel',
#   'sciName': 'Macronectes giganteus',
#   'locId': 'L592898',
#   'locName': 'Puerto Williams',
#   'obsDt': '2022-01-01 14:31',
#   'howMany': 3,
#   'lat': -54.9331831,
#   'lng': -67.6041985,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99949872'},
#  {'speciesCode': 'magcor1',
#   'comName': 'Magellanic Cormorant',
#   'sciName': 'Leucocarbo magellanicus',
#   'locId': 'L592898',
#   'locName': 'Puerto Williams',
#   'obsDt': '2022-01-01 14:31',
#   'howMany': 4,
#   'lat': -54.9331831,
#   'lng': -67.6041985,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99949872'},
#  {'speciesCode': 'bcbeag1',
#   'comName': 'Black-chested Buzzard-Eagle',
#   'sciName': 'Geranoaetus melanoleucus',
#   'locId': 'L17296557',
#   'locName': 'Villa Serrano',
#   'obsDt': '2022-01-01 14:30',
#   'howMany': 2,
#   'lat': -51.2319033,
#   'lng': -72.9743239,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99942869'},
#  {'speciesCode': 'rinkin1',
#   'comName': 'Ringed Kingfisher',
#   'sciName': 'Megaceryle torquata',
#   'locId': 'L17296557',
#   'locName': 'Villa Serrano',
#   'obsDt': '2022-01-01 14:30',
#   'howMany': 1,
#   'lat': -51.2319033,
#   'lng': -72.9743239,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99942869'},
#  {'speciesCode': 'auspar1',
#   'comName': 'Austral Parakeet',
#   'sciName': 'Enicognathus ferrugineus',
#   'locId': 'L17296557',
#   'locName': 'Villa Serrano',
#   'obsDt': '2022-01-01 14:30',
#   'howMany': 2,
#   'lat': -51.2319033,
#   'lng': -72.9743239,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99942869'},
#  {'speciesCode': 'plsfin1',
#   'comName': 'Plumbeous Sierra Finch',
#   'sciName': 'Geospizopsis unicolor',
#   'locId': 'L17296557',
#   'locName': 'Villa Serrano',
#   'obsDt': '2022-01-01 14:30',
#   'howMany': 2,
#   'lat': -51.2319033,
#   'lng': -72.9743239,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99942869'},
#  {'speciesCode': 'mosfin1',
#   'comName': 'Mourning Sierra Finch',
#   'sciName': 'Rhopospina fruticeti',
#   'locId': 'L17287642',
#   'locName': 'Petroglifos Quebrada De Culimo',
#   'obsDt': '2022-01-01 14:14',
#   'howMany': 3,
#   'lat': -32.0406919,
#   'lng': -71.2179222,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100006887'},
#  {'speciesCode': 'snoplo5',
#   'comName': 'Snowy Plover',
#   'sciName': 'Anarhynchus nivosus',
#   'locId': 'L636004',
#   'locName': 'Estero Tongoy--Desembocadura',
#   'obsDt': '2022-01-01 13:46',
#   'howMany': 2,
#   'lat': -30.25497,
#   'lng': -71.49359,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100001480'},
#  {'speciesCode': 'margod',
#   'comName': 'Marbled Godwit',
#   'sciName': 'Limosa fedoa',
#   'locId': 'L636004',
#   'locName': 'Estero Tongoy--Desembocadura',
#   'obsDt': '2022-01-01 13:46',
#   'howMany': 1,
#   'lat': -30.25497,
#   'lng': -71.49359,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': False,
#   'subId': 'S100001480'},
#  {'speciesCode': 'willet1',
#   'comName': 'Willet',
#   'sciName': 'Tringa semipalmata',
#   'locId': 'L636004',
#   'locName': 'Estero Tongoy--Desembocadura',
#   'obsDt': '2022-01-01 13:46',
#   'howMany': 3,
#   'lat': -30.25497,
#   'lng': -71.49359,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100001480'},
#  {'speciesCode': 'eleter1',
#   'comName': 'Elegant Tern',
#   'sciName': 'Thalasseus elegans',
#   'locId': 'L636004',
#   'locName': 'Estero Tongoy--Desembocadura',
#   'obsDt': '2022-01-01 13:46',
#   'howMany': 278,
#   'lat': -30.25497,
#   'lng': -71.49359,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100001480'},
#  {'speciesCode': 'spfgal1',
#   'comName': 'Spot-flanked Gallinule',
#   'sciName': 'Porphyriops melanops',
#   'locId': 'L5676207',
#   'locName': 'Embalse Culimo',
#   'obsDt': '2022-01-01 13:11',
#   'lat': -32.0732656,
#   'lng': -71.2277126,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100006890'},
#  {'speciesCode': 'magplo1',
#   'comName': 'Magellanic Plover',
#   'sciName': 'Pluvianellus socialis',
#   'locId': 'L981686',
#   'locName': 'Laguna Verde',
#   'obsDt': '2022-01-01 11:56',
#   'howMany': 2,
#   'lat': -53.1879333,
#   'lng': -70.3413391,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99835348'},
#  {'speciesCode': 'rucdot1',
#   'comName': 'Rufous-chested Dotterel',
#   'sciName': 'Zonibyx modestus',
#   'locId': 'L981686',
#   'locName': 'Laguna Verde',
#   'obsDt': '2022-01-01 11:56',
#   'howMany': 1,
#   'lat': -53.1879333,
#   'lng': -70.3413391,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99835348'},
#  {'speciesCode': 'sctear1',
#   'comName': 'Scale-throated Earthcreeper',
#   'sciName': 'Upucerthia dumetaria',
#   'locId': 'L981686',
#   'locName': 'Laguna Verde',
#   'obsDt': '2022-01-01 11:56',
#   'howMany': 1,
#   'lat': -53.1879333,
#   'lng': -70.3413391,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99835348'},
#  {'speciesCode': 'grbfir1',
#   'comName': 'Green-backed Firecrown',
#   'sciName': 'Sephanoides sephaniodes',
#   'locId': 'L807764',
#   'locName': 'Las Quemas Altas',
#   'obsDt': '2022-01-01 11:54',
#   'howMany': 1,
#   'lat': -40.6284479,
#   'lng': -73.117919,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99817676'},
#  {'speciesCode': 'hrshaw',
#   'comName': "Harris's Hawk",
#   'sciName': 'Parabuteo unicinctus',
#   'locId': 'L947356',
#   'locName': 'Moncul',
#   'obsDt': '2022-01-01 11:39',
#   'howMany': 1,
#   'lat': -38.7467871,
#   'lng': -73.4363937,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99855617'},
#  {'speciesCode': 'pafear1',
#   'comName': 'Patagonian Forest Earthcreeper',
#   'sciName': 'Upucerthia saturatior',
#   'locId': 'L947356',
#   'locName': 'Moncul',
#   'obsDt': '2022-01-01 11:39',
#   'howMany': 1,
#   'lat': -38.7467871,
#   'lng': -73.4363937,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99855617'},
#  {'speciesCode': 'ashgoo1',
#   'comName': 'Ashy-headed Goose',
#   'sciName': 'Chloephaga poliocephala',
#   'locId': 'L7988120',
#   'locName': 'Leñadura, Nuestra casa',
#   'obsDt': '2022-01-01 11:20',
#   'howMany': 3,
#   'lat': -53.2145727,
#   'lng': -70.9476647,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99865190'},
#  {'speciesCode': 'categr1',
#   'comName': 'Western Cattle-Egret',
#   'sciName': 'Ardea ibis',
#   'locId': 'L17273778',
#   'locName': 'S-36, Carahue, Araucanía, CL (-38.696, -73.293)',
#   'obsDt': '2022-01-01 11:16',
#   'howMany': 1,
#   'lat': -38.6956069,
#   'lng': -73.2930384,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99814504'},
#  {'speciesCode': 'brnowl',
#   'comName': 'American Barn Owl',
#   'sciName': 'Tyto furcata',
#   'locId': 'L7701763',
#   'locName': 'Sector San Juan, Florida',
#   'obsDt': '2022-01-01 11:00',
#   'howMany': 1,
#   'lat': -36.8176164,
#   'lng': -72.7719811,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100508972'},
#  {'speciesCode': 'rulowl1',
#   'comName': 'Rufous-legged Owl',
#   'sciName': 'Strix rufipes',
#   'locId': 'L7701763',
#   'locName': 'Sector San Juan, Florida',
#   'obsDt': '2022-01-01 11:00',
#   'howMany': 1,
#   'lat': -36.8176164,
#   'lng': -72.7719811,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': True,
#   'subId': 'S100508972'},
#  {'speciesCode': 'slbpar1',
#   'comName': 'Slender-billed Parakeet',
#   'sciName': 'Enicognathus leptorhynchus',
#   'locId': 'L9306153',
#   'locName': 'Molco, Los Corrales (-39,33, -72,091)',
#   'obsDt': '2022-01-01 11:00',
#   'howMany': 5,
#   'lat': -39.3299733,
#   'lng': -72.0909582,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100085677'},
#  {'speciesCode': 'cthhue1',
#   'comName': 'Chestnut-throated Huet-huet',
#   'sciName': 'Pteroptochos castaneus',
#   'locId': 'L7701763',
#   'locName': 'Sector San Juan, Florida',
#   'obsDt': '2022-01-01 11:00',
#   'howMany': 1,
#   'lat': -36.8176164,
#   'lng': -72.7719811,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100508972'},
#  {'speciesCode': 'bthhue1',
#   'comName': 'Black-throated Huet-huet',
#   'sciName': 'Pteroptochos tarnii',
#   'locId': 'L9306153',
#   'locName': 'Molco, Los Corrales (-39,33, -72,091)',
#   'obsDt': '2022-01-01 11:00',
#   'howMany': 1,
#   'lat': -39.3299733,
#   'lng': -72.0909582,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100085677'},
#  {'speciesCode': 'ocftap1',
#   'comName': 'Ochre-flanked Tapaculo',
#   'sciName': 'Eugralla paradoxa',
#   'locId': 'L7701763',
#   'locName': 'Sector San Juan, Florida',
#   'obsDt': '2022-01-01 11:00',
#   'howMany': 1,
#   'lat': -36.8176164,
#   'lng': -72.7719811,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': True,
#   'subId': 'S100508972'},
#  {'speciesCode': 'magtap1',
#   'comName': 'Magellanic Tapaculo',
#   'sciName': 'Scytalopus magellanicus',
#   'locId': 'L9306153',
#   'locName': 'Molco, Los Corrales (-39,33, -72,091)',
#   'obsDt': '2022-01-01 11:00',
#   'howMany': 1,
#   'lat': -39.3299733,
#   'lng': -72.0909582,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100085677'},
#  {'speciesCode': 'shbmin1',
#   'comName': 'Short-billed Miner',
#   'sciName': 'Geositta antarctica',
#   'locId': 'L5001855',
#   'locName': 'Laguna Barrosa--Parcelas',
#   'obsDt': '2022-01-01 10:37',
#   'howMany': 2,
#   'lat': -53.1001055,
#   'lng': -70.2584696,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S99834982'},
#  {'speciesCode': 'saffin',
#   'comName': 'Saffron Finch',
#   'sciName': 'Sicalis flaveola',
#   'locId': 'L15715069',
#   'locName': 'Plaza de Purén',
#   'obsDt': '2022-01-01 10:25',
#   'howMany': 1,
#   'lat': -38.0334112,
#   'lng': -73.0727586,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99809940'},
#  {'speciesCode': 'bwgdov1',
#   'comName': 'Black-winged Ground Dove',
#   'sciName': 'Metriopelia melanoptera',
#   'locId': 'L1306146',
#   'locName': 'Los maitenes 32°48´S 70°22´47; San Esteban',
#   'obsDt': '2022-01-01 10:00',
#   'lat': -32.8025704,
#   'lng': -70.3799629,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100442664'},
#  {'speciesCode': 'moutur1',
#   'comName': 'Moustached Turca',
#   'sciName': 'Pteroptochos megapodius',
#   'locId': 'L1306146',
#   'locName': 'Los maitenes 32°48´S 70°22´47; San Esteban',
#   'obsDt': '2022-01-01 10:00',
#   'lat': -32.8025704,
#   'lng': -70.3799629,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100442664'},
#  {'speciesCode': 'whttap1',
#   'comName': 'White-throated Tapaculo',
#   'sciName': 'Scelorchilus albicollis',
#   'locId': 'L1306146',
#   'locName': 'Los maitenes 32°48´S 70°22´47; San Esteban',
#   'obsDt': '2022-01-01 10:00',
#   'lat': -32.8025704,
#   'lng': -70.3799629,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S100442664'},
#  {'speciesCode': 'btsfin1',
#   'comName': 'Band-tailed Sierra Finch',
#   'sciName': 'Rhopospina alaudina',
#   'locId': 'L11275353',
#   'locName': 'Los Cuatro Vientos',
#   'obsDt': '2022-01-01 09:05',
#   'howMany': 2,
#   'lat': -34.0375055,
#   'lng': -70.7478824,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S106238258'},
#  {'speciesCode': 'cincon1',
#   'comName': 'Cinereous Conebill',
#   'sciName': 'Conirostrum cinereum',
#   'locId': 'L8338994',
#   'locName': 'Casa, plaza',
#   'obsDt': '2022-01-01 08:16',
#   'howMany': 3,
#   'lat': -18.4748607,
#   'lng': -70.2880568,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99810831'},
#  {'speciesCode': 'andgul1',
#   'comName': 'Andean Gull',
#   'sciName': 'Chroicocephalus serranus',
#   'locId': 'L16489852',
#   'locName': 'Minera Los Pelambres',
#   'obsDt': '2022-01-01 08:00',
#   'howMany': 1,
#   'lat': -31.7092573,
#   'lng': -70.4881954,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S99854103'},
#  {'speciesCode': 'perter2',
#   'comName': 'Peruvian Tern',
#   'sciName': 'Sternula lorata',
#   'locId': 'L21622376',
#   'locName': 'Caleta Punta Lagarto',
#   'obsDt': '2022-01-01 08:00',
#   'howMany': 1,
#   'lat': -23.3896544,
#   'lng': -70.6000291,
#   'obsValid': True,
#   'obsReviewed': True,
#   'locationPrivate': True,
#   'subId': 'S122923968'},
#  {'speciesCode': 'lesrhe2',
#   'comName': 'Lesser Rhea',
#   'sciName': 'Rhea pennata',
#   'locId': 'L38905203',
#   'locName': 'Y-415',
#   'obsDt': '2022-01-01 07:30',
#   'howMany': 5,
#   'lat': -52.0788,
#   'lng': -70.2006,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S206780776'},
#  {'speciesCode': 'kelgoo1',
#   'comName': 'Kelp Goose',
#   'sciName': 'Chloephaga hybrida',
#   'locId': 'L38905203',
#   'locName': 'Y-415',
#   'obsDt': '2022-01-01 07:30',
#   'howMany': 1,
#   'lat': -52.0788,
#   'lng': -70.2006,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S206780776'},
#  {'speciesCode': 'tatdot1',
#   'comName': 'Tawny-throated Dotterel',
#   'sciName': 'Oreopholus ruficollis',
#   'locId': 'L38905203',
#   'locName': 'Y-415',
#   'obsDt': '2022-01-01 07:30',
#   'howMany': 60,
#   'lat': -52.0788,
#   'lng': -70.2006,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S206780776'},
#  {'speciesCode': 'leasee1',
#   'comName': 'Least Seedsnipe',
#   'sciName': 'Thinocorus rumicivorus',
#   'locId': 'L38905203',
#   'locName': 'Y-415',
#   'obsDt': '2022-01-01 07:30',
#   'howMany': 6,
#   'lat': -52.0788,
#   'lng': -70.2006,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S206780776'},
#  {'speciesCode': 'chvtyr2',
#   'comName': 'Chocolate-vented Tyrant',
#   'sciName': 'Neoxolmis rufiventris',
#   'locId': 'L38905203',
#   'locName': 'Y-415',
#   'obsDt': '2022-01-01 07:30',
#   'howMany': 7,
#   'lat': -52.0788,
#   'lng': -70.2006,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S206780776'},
#  {'speciesCode': 'cawfin1',
#   'comName': 'White-bridled Finch',
#   'sciName': 'Melanodera melanodera',
#   'locId': 'L38905203',
#   'locName': 'Y-415',
#   'obsDt': '2022-01-01 07:30',
#   'howMany': 2,
#   'lat': -52.0788,
#   'lng': -70.2006,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': True,
#   'subId': 'S206780776'},
#  {'speciesCode': 'comgal1',
#   'comName': 'Common Gallinule',
#   'sciName': 'Gallinula galeata',
#   'locId': 'L668852',
#   'locName': 'Río Lluta--Desembocadura',
#   'obsDt': '2022-01-01 07:15',
#   'howMany': 4,
#   'lat': -18.4165392,
#   'lng': -70.3224081,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100036469'},
#  {'speciesCode': 'killde',
#   'comName': 'Killdeer',
#   'sciName': 'Charadrius vociferus',
#   'locId': 'L668852',
#   'locName': 'Río Lluta--Desembocadura',
#   'obsDt': '2022-01-01 07:15',
#   'howMany': 3,
#   'lat': -18.4165392,
#   'lng': -70.3224081,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100036469'},
#  {'speciesCode': 'permea1',
#   'comName': 'Peruvian Meadowlark',
#   'sciName': 'Leistes bellicosus',
#   'locId': 'L668852',
#   'locName': 'Río Lluta--Desembocadura',
#   'obsDt': '2022-01-01 07:15',
#   'howMany': 2,
#   'lat': -18.4165392,
#   'lng': -70.3224081,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100036469'},
#  {'speciesCode': 'slbfin3',
#   'comName': 'Slender-billed Finch',
#   'sciName': 'Xenospingus concolor',
#   'locId': 'L668852',
#   'locName': 'Río Lluta--Desembocadura',
#   'obsDt': '2022-01-01 07:15',
#   'howMany': 3,
#   'lat': -18.4165392,
#   'lng': -70.3224081,
#   'obsValid': True,
#   'obsReviewed': False,
#   'locationPrivate': False,
#   'subId': 'S100036469'}]

# %% [markdown]
# Ahora que verificamos que esta todo correcto, usamos datetime, con ayuda de https://es.stackoverflow.com/a/110963, para poder manejar fechas, y por cada fecha en el rango pedido, descarghamos la informacion y la juntamos en una sola lista

# %%
inicio = datetime.datetime(2022, 1, 1)
final = datetime.datetime(2025, 7, 31)
diferencia = (final - inicio).days

lista_fechas = [inicio + datetime.timedelta(days=d) for d in range(diferencia + 1)]
lista_fechas

datos = []

for fecha in lista_fechas:
    y = str(fecha.year)
    m = str(fecha.month)
    d = str(fecha.day)

    url = f"https://api.ebird.org/v2/data/obs/{regionCode}/historic/{y}/{m}/{d}"
    headers = {
        'X-eBirdApiToken':'idff0s6in775'
    }

    respuesta = requests.get(url, headers=headers)
    respuesta = respuesta.json()

    datos.append(respuesta)

datos
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ConnectionAbortedError: [WinError 10053] Se ha anulado una conexión establecida por el software en su equipo host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# ProtocolError: ('Connection aborted.', ConnectionAbortedError(10053, 'Se ha anulado una conexión establecida por el software en su equipo host', None, 10053, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[4], line 21
#      16 url = f"https://api.ebird.org/v2/data/obs/{regionCode}/historic/{y}/{m}/{d}"
#      17 headers = {
#      18     'X-eBirdApiToken':'idff0s6in775'
#      19 }
# ---> 21 respuesta = requests.get(url, headers=headers)
#      22 respuesta = respuesta.json()
#      24 datos.append(respuesta)
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\crist\OneDrive - Universidad Católica de Chile\Escritorio\Estudio\2° Semestre\IIC2233\intro_cd\Lib\site-packages\requests\adapters.py:659, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#    (...)    655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
# --> 659     raise ConnectionError(err, request=request)
#     661 except MaxRetryError as e:
#     662     if isinstance(e.reason, ConnectTimeoutError):
#     663         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionAbortedError(10053, 'Se ha anulado una conexión establecida por el software en su equipo host', None, 10053, None))

# %% [markdown]
# Ahora que tenemos los datos, para no tener que pedirlos cada vez que nos metamos a la tarea, guardo el archivo en un csv, despues de concatenar todos los dias en un solo dataframe

# %%
df = pd.DataFrame(datos)
df.info()

df = pd.DataFrame()

for dia in datos:
    nuevo_df = pd.DataFrame(dia)
    df = pd.concat([df, nuevo_df], axis=0)

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Columns: 340 entries, 0 to 339
# dtypes: object(340)
# memory usage: 3.4+ MB
#   speciesCode                  comName                sciName      locId  \
# 0     soulap1         Southern Lapwing     Vanellus chilensis  L10140471
# 1     bkfibi1         Black-faced Ibis  Theristicus melanopis   L7988120
# 2     grhowl2        Lesser Horned Owl      Bubo magellanicus   L7988120
# 3     austhr1           Austral Thrush     Turdus falcklandii   L7988120
# 4     rucspa1  Rufous-collared Sparrow   Zonotrichia capensis   L7988120
#
#                                              locName             obsDt  \
# 0  Villa Parque Austral, Osorno, Región de los La...  2022-01-01 23:41
# 1                             Leñadura, Nuestra casa  2022-01-01 22:18
# 2                             Leñadura, Nuestra casa  2022-01-01 22:18
# 3                             Leñadura, Nuestra casa  2022-01-01 22:18
# 4                             Leñadura, Nuestra casa  2022-01-01 22:18
#
#    howMany        lat        lng  obsValid  obsReviewed  locationPrivate  \
# 0      3.0 -40.585844 -73.113157      True        False             True
# 1      4.0 -53.214573 -70.947665      True        False             True
# 2      1.0 -53.214573 -70.947665      True        False             True
# 3      1.0 -53.214573 -70.947665      True        False             True
# 4      2.0 -53.214573 -70.947665      True        False             True
#
#         subId exoticCategory
# 0   S99916680            NaN
# 1  S100024876            NaN
# 2  S100024876            NaN
# 3  S100024876            NaN
# 4  S100024876            NaN

# %%
df.to_csv("datos tarea 2.csv", index=False)

# %% [markdown]
# Ahora usamos como dataframe el archivo guardado

# %%
df = pd.read_csv("datos tarea 2.csv")
df.head()
# Out:
#   speciesCode                  comName                sciName      locId  \
# 0     soulap1         Southern Lapwing     Vanellus chilensis  L10140471
# 1     bkfibi1         Black-faced Ibis  Theristicus melanopis   L7988120
# 2     grhowl2        Lesser Horned Owl      Bubo magellanicus   L7988120
# 3     austhr1           Austral Thrush     Turdus falcklandii   L7988120
# 4     rucspa1  Rufous-collared Sparrow   Zonotrichia capensis   L7988120
#
#                                              locName             obsDt  \
# 0  Villa Parque Austral, Osorno, Región de los La...  2022-01-01 23:41
# 1                             Leñadura, Nuestra casa  2022-01-01 22:18
# 2                             Leñadura, Nuestra casa  2022-01-01 22:18
# 3                             Leñadura, Nuestra casa  2022-01-01 22:18
# 4                             Leñadura, Nuestra casa  2022-01-01 22:18
#
#    howMany        lat        lng  obsValid  obsReviewed  locationPrivate  \
# 0      3.0 -40.585844 -73.113157      True        False             True
# 1      4.0 -53.214573 -70.947665      True        False             True
# 2      1.0 -53.214573 -70.947665      True        False             True
# 3      1.0 -53.214573 -70.947665      True        False             True
# 4      2.0 -53.214573 -70.947665      True        False             True
#
#         subId exoticCategory
# 0   S99916680            NaN
# 1  S100024876            NaN
# 2  S100024876            NaN
# 3  S100024876            NaN
# 4  S100024876            NaN

# %%
# Respuesta a
respuesta = f"El dataset tiene {len(df)} avistamientos"
respuesta
# Out:
# 'El dataset tiene 272183 avistamientos'

# %% [markdown]
# Como value counts ya ordena de mayor a menor no hay que hacer nada. Podemos apreciar que hay muchos empates en la parte de arriba y la parte de abajo, esto se debe porque entre las fechas seleccionadas hay 1308 dias, por lo tanto son todos los pajaros que se ven a diario, por otro lado, todos los empatados con 1, son aquellos pajaros exoticos que no se suelen ver

# %%
# Respuesta b
df["speciesCode"].value_counts()
# Out:
# speciesCode
# chimoc1    1308
# brhgul2    1308
# rutpla1    1308
# dabcin1    1308
# thtray1    1308
#            ...
# dickci        1
# swagoo1       1
# wooduc        1
# rudduc        1
# stbtyr1       1
# Name: count, Length: 533, dtype: int64

# %% [markdown]
# ### 3.2 Tranformación (1 punto)

# %% [markdown]
# **a) (0.5 pts)** Transforme la columna `obsDt` de string a un objeto de tipo `datetime` únicamente con año, mes y día (YYYY-MM-DD). Luego, agregue las siguientes nuevas columnas:
# * `month` con únicamente el mes del avistamiento (puede dejar el mes como número entero de 1 a 12).
# * `year-month` con el mes y año fecha en formato YYYY-MM

# %% [markdown]
# Aca para limpiar los datos erroneos como 2022-01-0 me lei la documentacion de la funcion incluida en la "Pandas-Cheat-Sheet.pdf" incluida en el repositorio del curso : https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html (la documentacion me llevo a conocer strftime en la seccion del parametro "format : str, default None"). Pero eso me llevo a un formato donde el ano salia sin el 20 del principio, por ende, se lo sume, y como se trandformo a object, lo transforme nuevamente a datetime

# %%
# Respuesta
df_test = df.copy()

df_test.sort_values(["obsDt"])

df_test["obsDt"] = pd.to_datetime(df_test["obsDt"], errors="coerce")
df_test["obsDt"] = df_test["obsDt"].dt.strftime("20%y-%m-%d")
df_test["obsDt"] = pd.to_datetime(df_test["obsDt"], errors="coerce")


df_test.sort_values(["obsDt"])
df_test.info()
df_test
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272183 entries, 0 to 272182
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   speciesCode      272183 non-null  object
#  1   comName          272183 non-null  object
#  2   sciName          272183 non-null  object
#  3   locId            272183 non-null  object
#  4   locName          272183 non-null  object
#  5   obsDt            271571 non-null  datetime64[ns]
#  6   howMany          266880 non-null  float64
#  7   lat              272183 non-null  float64
#  8   lng              272183 non-null  float64
#  9   obsValid         272183 non-null  bool
#  10  obsReviewed      272183 non-null  bool
#  11  locationPrivate  272183 non-null  bool
#  12  subId            272183 non-null  object
#  13  exoticCategory   6963 non-null    object
# dtypes: bool(3), datetime64[ns](1), float64(3), object(7)
# memory usage: 23.6+ MB
#        speciesCode                       comName                   sciName  \
# 0          soulap1              Southern Lapwing        Vanellus chilensis
# 1          bkfibi1              Black-faced Ibis     Theristicus melanopis
# 2          grhowl2             Lesser Horned Owl         Bubo magellanicus
# 3          austhr1                Austral Thrush        Turdus falcklandii
# 4          rucspa1       Rufous-collared Sparrow      Zonotrichia capensis
# ...            ...                           ...                       ...
# 272178     wbctyr1      White-browed Chat-Tyrant      Ochthoeca leucophrys
# 272179     baytan3       Blue-and-yellow Tanager       Rauenia bonariensis
# 272180     bktflo1  Black-throated Flowerpiercer   Diglossa brunneiventris
# 272181     rngtyr1    Rufous-naped Ground-Tyrant  Muscisaxicola rufivertex
# 272182     orntin1                Ornate Tinamou        Nothoprocta ornata
#
#             locId                                            locName  \
# 0       L10140471  Villa Parque Austral, Osorno, Región de los La...
# 1        L7988120                             Leñadura, Nuestra casa
# 2        L7988120                             Leñadura, Nuestra casa
# 3        L7988120                             Leñadura, Nuestra casa
# 4        L7988120                             Leñadura, Nuestra casa
# ...           ...                                                ...
# 272178    L570508                                              Putre
# 272179    L570508                                              Putre
# 272180    L570508                                              Putre
# 272181  L39684723  Coronel Alcerreca, Arica y Parinacota, CL (-17...
# 272182  L50761049  Ruta 11 CH, Putre CL-Arica y Parinacota Region...
#
#             obsDt  howMany        lat        lng  obsValid  obsReviewed  \
# 0      2022-01-01      3.0 -40.585844 -73.113157      True        False
# 1      2022-01-01      4.0 -53.214573 -70.947665      True        False
# 2      2022-01-01      1.0 -53.214573 -70.947665      True        False
# 3      2022-01-01      1.0 -53.214573 -70.947665      True        False
# 4      2022-01-01      2.0 -53.214573 -70.947665      True        False
# ...           ...      ...        ...        ...       ...          ...
# 272178 2025-07-31      2.0 -18.196454 -69.556568      True        False
# 272179 2025-07-31      2.0 -18.196454 -69.556568      True        False
# 272180 2025-07-31      1.0 -18.196454 -69.556568      True        False
# 272181 2025-07-31      4.0 -17.992459 -69.660757      True        False
# 272182 2025-07-31      5.0 -18.187173 -69.520307      True        False
#
#         locationPrivate       subId exoticCategory
# 0                  True   S99916680            NaN
# 1                  True  S100024876            NaN
# 2                  True  S100024876            NaN
# 3                  True  S100024876            NaN
# 4                  True  S100024876            NaN
# ...                 ...         ...            ...
# 272178            False  S263980121            NaN
# 272179            False  S263980121            NaN
# 272180            False  S263980121            NaN
# 272181             True  S264055602            NaN
# 272182             True  S263954896            NaN
#
# [272183 rows x 14 columns]

# %% [markdown]
# En este paso aplique lo usado en el paso anterior

# %%
df_nuevo = df_test.copy()
df_nuevo

df_nuevo["month"] = df_nuevo["obsDt"].copy()
df_nuevo

df_nuevo["month"] = df_nuevo["month"].dt.strftime("%m")
df_nuevo

df_nuevo["year-month"] = df_nuevo["obsDt"].copy().dt.strftime("20%y-%m")
df_nuevo
# Out:
#        speciesCode                       comName                   sciName  \
# 0          soulap1              Southern Lapwing        Vanellus chilensis
# 1          bkfibi1              Black-faced Ibis     Theristicus melanopis
# 2          grhowl2             Lesser Horned Owl         Bubo magellanicus
# 3          austhr1                Austral Thrush        Turdus falcklandii
# 4          rucspa1       Rufous-collared Sparrow      Zonotrichia capensis
# ...            ...                           ...                       ...
# 272178     wbctyr1      White-browed Chat-Tyrant      Ochthoeca leucophrys
# 272179     baytan3       Blue-and-yellow Tanager       Rauenia bonariensis
# 272180     bktflo1  Black-throated Flowerpiercer   Diglossa brunneiventris
# 272181     rngtyr1    Rufous-naped Ground-Tyrant  Muscisaxicola rufivertex
# 272182     orntin1                Ornate Tinamou        Nothoprocta ornata
#
#             locId                                            locName  \
# 0       L10140471  Villa Parque Austral, Osorno, Región de los La...
# 1        L7988120                             Leñadura, Nuestra casa
# 2        L7988120                             Leñadura, Nuestra casa
# 3        L7988120                             Leñadura, Nuestra casa
# 4        L7988120                             Leñadura, Nuestra casa
# ...           ...                                                ...
# 272178    L570508                                              Putre
# 272179    L570508                                              Putre
# 272180    L570508                                              Putre
# 272181  L39684723  Coronel Alcerreca, Arica y Parinacota, CL (-17...
# 272182  L50761049  Ruta 11 CH, Putre CL-Arica y Parinacota Region...
#
#             obsDt  howMany        lat        lng  obsValid  obsReviewed  \
# 0      2022-01-01      3.0 -40.585844 -73.113157      True        False
# 1      2022-01-01      4.0 -53.214573 -70.947665      True        False
# 2      2022-01-01      1.0 -53.214573 -70.947665      True        False
# 3      2022-01-01      1.0 -53.214573 -70.947665      True        False
# 4      2022-01-01      2.0 -53.214573 -70.947665      True        False
# ...           ...      ...        ...        ...       ...          ...
# 272178 2025-07-31      2.0 -18.196454 -69.556568      True        False
# 272179 2025-07-31      2.0 -18.196454 -69.556568      True        False
# 272180 2025-07-31      1.0 -18.196454 -69.556568      True        False
# 272181 2025-07-31      4.0 -17.992459 -69.660757      True        False
# 272182 2025-07-31      5.0 -18.187173 -69.520307      True        False
#
#         locationPrivate       subId exoticCategory month year-month
# 0                  True   S99916680            NaN    01    2022-01
# 1                  True  S100024876            NaN    01    2022-01
# 2                  True  S100024876            NaN    01    2022-01
# 3                  True  S100024876            NaN    01    2022-01
# 4                  True  S100024876            NaN    01    2022-01
# ...                 ...         ...            ...   ...        ...
# 272178            False  S263980121            NaN    07    2025-07
# 272179            False  S263980121            NaN    07    2025-07
# 272180            False  S263980121            NaN    07    2025-07
# 272181             True  S264055602            NaN    07    2025-07
# 272182             True  S263954896            NaN    07    2025-07
#
# [272183 rows x 16 columns]

# %% [markdown]
# **b) (0.5 pts)** Averigue cómo tranformar su DataFrame de Pandas en un GeoDataFrame de GeoPandas. Para esto, utilice las columnas `lat`y `lng` para generar los puntos de la nueva columna `geometry`. Para las visualizaciones siguientes utilizaremos el Coordinate Reference System (CRS) EPSG 4326 (también llamado [WGS 84](https://es.wikipedia.org/wiki/WGS84)). Asegúrese que sus coordenadas correspondan a este CRS al crear su GeoDataFrame.

# %% [markdown]
# Para este paso use lo indicado en https://geopandas-org.translate.goog/en/stable/gallery/create_geopandas_from_pandas.html?_x_tr_sl=en&_x_tr_tl=es&_x_tr_hl=es&_x_tr_pto=tc para generar el geodataframe

# %%
# Respuesta
gdf = df_nuevo.copy()
gdf = gpd.GeoDataFrame(gdf, geometry=gpd.points_from_xy(gdf["lng"], gdf["lat"]), crs="EPSG:4326")
gdf
# Out:
#        speciesCode                       comName                   sciName  \
# 0          soulap1              Southern Lapwing        Vanellus chilensis
# 1          bkfibi1              Black-faced Ibis     Theristicus melanopis
# 2          grhowl2             Lesser Horned Owl         Bubo magellanicus
# 3          austhr1                Austral Thrush        Turdus falcklandii
# 4          rucspa1       Rufous-collared Sparrow      Zonotrichia capensis
# ...            ...                           ...                       ...
# 272178     wbctyr1      White-browed Chat-Tyrant      Ochthoeca leucophrys
# 272179     baytan3       Blue-and-yellow Tanager       Rauenia bonariensis
# 272180     bktflo1  Black-throated Flowerpiercer   Diglossa brunneiventris
# 272181     rngtyr1    Rufous-naped Ground-Tyrant  Muscisaxicola rufivertex
# 272182     orntin1                Ornate Tinamou        Nothoprocta ornata
#
#             locId                                            locName  \
# 0       L10140471  Villa Parque Austral, Osorno, Región de los La...
# 1        L7988120                             Leñadura, Nuestra casa
# 2        L7988120                             Leñadura, Nuestra casa
# 3        L7988120                             Leñadura, Nuestra casa
# 4        L7988120                             Leñadura, Nuestra casa
# ...           ...                                                ...
# 272178    L570508                                              Putre
# 272179    L570508                                              Putre
# 272180    L570508                                              Putre
# 272181  L39684723  Coronel Alcerreca, Arica y Parinacota, CL (-17...
# 272182  L50761049  Ruta 11 CH, Putre CL-Arica y Parinacota Region...
#
#             obsDt  howMany        lat        lng  obsValid  obsReviewed  \
# 0      2022-01-01      3.0 -40.585844 -73.113157      True        False
# 1      2022-01-01      4.0 -53.214573 -70.947665      True        False
# 2      2022-01-01      1.0 -53.214573 -70.947665      True        False
# 3      2022-01-01      1.0 -53.214573 -70.947665      True        False
# 4      2022-01-01      2.0 -53.214573 -70.947665      True        False
# ...           ...      ...        ...        ...       ...          ...
# 272178 2025-07-31      2.0 -18.196454 -69.556568      True        False
# 272179 2025-07-31      2.0 -18.196454 -69.556568      True        False
# 272180 2025-07-31      1.0 -18.196454 -69.556568      True        False
# 272181 2025-07-31      4.0 -17.992459 -69.660757      True        False
# 272182 2025-07-31      5.0 -18.187173 -69.520307      True        False
#
#         locationPrivate       subId exoticCategory month year-month  \
# 0                  True   S99916680            NaN    01    2022-01
# 1                  True  S100024876            NaN    01    2022-01
# 2                  True  S100024876            NaN    01    2022-01
# 3                  True  S100024876            NaN    01    2022-01
# 4                  True  S100024876            NaN    01    2022-01
# ...                 ...         ...            ...   ...        ...
# 272178            False  S263980121            NaN    07    2025-07
# 272179            False  S263980121            NaN    07    2025-07
# 272180            False  S263980121            NaN    07    2025-07
# 272181             True  S264055602            NaN    07    2025-07
# 272182             True  S263954896            NaN    07    2025-07
#
#                            geometry
# 0       POINT (-73.11316 -40.58584)
# 1       POINT (-70.94766 -53.21457)
# 2       POINT (-70.94766 -53.21457)
# 3       POINT (-70.94766 -53.21457)
# 4       POINT (-70.94766 -53.21457)
# ...                             ...
# 272178  POINT (-69.55657 -18.19645)
# 272179  POINT (-69.55657 -18.19645)
# 272180  POINT (-69.55657 -18.19645)
# 272181  POINT (-69.66076 -17.99246)
# 272182  POINT (-69.52031 -18.18717)
#
# [272183 rows x 17 columns]

# %% [markdown]
# ### 3.3 Exploración del dataset (1 punto)
#
# **a) (0.3 pts)** Utilice `geopandas` para leer el archivo `Regional.shp` descargado de BCN. Asegúrese de que su CRS sea el mismo que utilizó en la sección anterior.

# %%
# Respuesta
nuevo_gdf = gdf.copy()
chile = gpd.read_file("Regional.shp")
chile = chile.to_crs("EPSG:4326")

# %% [markdown]
# **b) (0.7 pts)** Grafique un mapa de Chile con todos los avistamientos de su dataset como puntos en el mapa. Comente: ¿Cómo se distribuyen estos avistamientos? ¿Hay lugares en Chile donde haya una menor densidad de datos? ¿Cuáles?

# %% [markdown]
# Los avistamientos se distribuyen sobre el territorio nacional (incluyendo isla de pascua y otras islas), generando una menor densidad de avistamientos en la region de Antofagasta y en la union entre ka region de Aysen y Magallanes. Pero tambien hay avistamientos peculiares fuera del territorio terrestre de Chile, por ejemplo se genera una linea de avistamientos desde la zona centro del pais hacia el oceano pacifico, y hay un sector circular, como de un quinto de circunferencia, asomandose en la parte mas austral de la region de Magallanes.

# %%
# Respuesta
mapa = chile.plot()
nuevo_gdf.plot(ax=mapa, markersize=0.01, color="red")
# Out:
# <Axes: >

# %% [markdown]
# ### 3.4 Visualización de migraciones (2.5 puntos)
#
# **a) (0.2 pts)** Vamos a inspeccionar los avistamientos de las siguientes 2 especies en particular:
#
# * Run-run [(*Hymenops perspicillatus*)](https://www.avesdechile.cl/171.htm)
# * Dormilona tontita [(*Muscisaxicola maclovianus*)](https://www.avesdechile.cl/043.htm)
#
# Primero, genere dos nuevos dataframes con los avistamientos de cada especie por separado.

# %%
# Respuesta

# %% [markdown]
# **b) (0.8 pts)** Para cada una de estas especies, agrupe los datos según `year-month`. Luego, realice un gráfico que muestre la cantidad de avistamientos en el tiempo, empezando desde enero del 2022 hasta julio de 2025. Responda: ¿cómo varía cantidad de avistamientos para estas dos especies? ¿Cuáles son sus diferencias?

# %%
# Respuesta

# %% [markdown]
# **b) (1 pto)** Grafique en un mapa de Chile la ubicación de cada avistamiento para cada especie mencionada por separado. Utilice el color de cada punto como indicador del mes de avistamiento (columna `month`). Para esto, utilice un **colormap cíclico** para representar los meses del año. Puede utilizar el colormap disponible en la siguiente celda, o bien utilizar otro (siempre y cuando sea cíclico).

# %%
import matplotlib.colors as mcolors
colors = ["coral", "blue", "coral"]
positions = [0, 0.5, 1]

# Creamos un colormap cíclico para representar meses del año
custom_cmap = mcolors.LinearSegmentedColormap.from_list("cyclic_cmap", list(zip(positions, colors)))

# %%
# Respuesta

# %% [markdown]
# **c) (0.5 pts)** Describa las migraciones de estas dos especies. ¿Cómo se diferencian?

# %% [markdown]
# Respuesta
