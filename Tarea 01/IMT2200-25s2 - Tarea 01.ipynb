# %% [markdown]
# IMT 2200 - Introducción a Ciencia de Datos<br>
# **Pontificia Universidad Católica de Chile**<br>
# **Instituto de Ingeniería Matemática y Computacional**<br>
# **Semestre 2025-S2**<br>
# **Profesor:** Rodrigo A. Carrasco <br>
#
# ---
#
# ## Tarea 01 – Cargando y Analizando Datos
#
# - **Fecha de Entrega:** martes 26 de agosto de 2025, a las 23:59.
# -
# **Formato de entrega:** Notebook ejecutado y comentado (`.ipynb`) en l emódulo de Tara 01 habilitado en Canvas.

# %% [markdown]
# ## Instrucciones
#
# - Esta Tarea debe desarrollarse de manera totalmente *individual*, de acuerdo a lo establecido en la sección de Integridad Académica en el programa del curso.
# - La Tarea debe ser desarrollada en lenguaje de programación Python y la entrega en formato Jupyter Notebook.
# - El desarrollo del Notebook debe ser claro y ordenado, incluyendo anotaciones (markdown) y comentarios que permitan seguir fácilmente el código y los pasos implementados a los correctores, y siguiendo buenas prácticas de programación. La presentación y claridad del notebook y código forman parte de la evaluación de la tarea.
# - Notebook **autocontenible** que:
#    - Ejecute sin errores todas las celdas.
#   - Contenga tanto el código como los comentarios y explicaciones necesarias.
#   - Incluya visualizaciones claras y correctamente etiquetadas.
# - No se aceptarán notebooks con celdas rotas o que dependan de rutas externas no indicadas en la tara.
#
# - Deben hacer sus consultas y comentarios sobre la Tarea a traves del canal de Tareas en eo del curso en Canvas.os.
# cteriza.

# %% [markdown]
# ## 1. Objetivos
#
# - Aplicar los conceptos iniciales de manejo de datos y análisis exploratorio vistos en clases.
# - Practicar la lectura, limpieza y manipulación de datos en Python.
# - Desarrollar habilidades para visualizar y describir patrones y tendencias en conjuntos de datos reales.
# - Fomentar la capacidad de comunicar resultados de forma clara y fundamentada.
#
# ### 1.1 Objetivo educacional
#
# Esta Tarea tiene como objetivo que los estudiantes desarrollen la capacidad de manejar algunas de las librerías centrales para el desarrollo de Ciencia de Datos, con foco en la lectura y exploración de datos.
#
# Para los ejercicios a continuación, usted deberá leer, inspeccionar, manipular y graficar conjuntos de datos en distintos formatos, de manera de responder las preguntas de cada parte de la Tarea.
#
# ### 1.2 Pregunta de ciencia de datos
#
# Para esta tarea, tendremos como objetivo comprender cómo han cambiado los juegos de mesa en los últimos 40 años. Específicamente queremos saber qué tipos de juegos se han vuelto más comunes hoy en día y qué los caracteriza.
#
# ### 1.3 Recomendaciones
# - Utiliza las librerías sugeridas en el notebook o justifica brevemente si incorporas otras.
# - Revisa que todas las celdas se ejecuten en orden, desde el inicio, sin errores.
# - Comenta tu código para explicar qué hace cada sección relevante.
# - Asegúrate de que las visualizaciones sean fáciles de interpretar y tengan títulos y etiquetas adecuados.

# %% [markdown]
# ## 2. Datos
#
# Estaremos utilizando información extraída desde [BoardGameGeek.com](https://boardgamegeek.com/), una plataforma para aficionados de los juegos de mesa, que permite a sus usuarios registrar, calificar e intercambiar sus juegos favoritos. Actualmente, BGG es una de las bases de datos más extensa y diversa de juegos de mesa.
#
# El dataset con el que trabajaremos consiste en un grupo de archivos CSV que contienen información sobre más de 100.000 juegos de mesa almacenados en la plataforma. Este puede descargarse directamente desde el siguiente enlace: https://www.kaggle.com/datasets/mshepherd/board-games Para descargar los datos, haga click en el botón de **Download**, donde podrá descargar los archivos como `.zip`, o bien utilizar la API de Kaggle.
#
# Para el desarrollo de esta tarea, solo utilizaremos los archivos con el prefijo `bgg_`.
#
# **Si utiliza la API de Kaggle para descargar los datos, deje el código utilizado en la siguiente celda:**

# %%
# Descarga de datos desde Kaggle

# %% [markdown]
# ### 2.1 Librerías
#
# Para esta tarea recomendamos al menos usar las librerías indicadas en la siguiente celda del Notebook. Puede agregar otras si lo estima conveniente para responder de mejor forma las preguntas de la Tarea.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Desarrollo
#
# Para cada una de las siguientes preguntas o actividades incluya una o más celdas de código y Markdown con las respuestas o comentarios necesarios para contestar la pregunta o lograr la actividad. Agregue sus celdas a continuación de cada pregunta para que el Notebook quede ordenado.
#
# En el caso de gráficos, figuras o tablas, asegúrese que todas tengan título, etiquetas en los ejes o haya claridad de los contenidos.

# %% [markdown]
# ### 3.1 DataFrame unificado (1 punto)
#
# Vamos a cargar en un DataFrame los datos de juegos guardados en el documento `bgg_GameItem.csv`. Al inspeccionar nuestros datos, podemos notar que los valores de ciertas comunas vienen "codificados" con ID. Para comenzar, vamos a juntar la información de los distintos archivos descargados.
#
# **a) (0.8 pts)** Genere un DataFrame único con toda la información de cada juego, incluyendo: nombres de artistas y diseñadores involucrados, mecánicas, categorías, tipo, familia y editorial. Guarde este DataFrame en un nuevo archivo CSV.

# %%
info_juegos = pd.read_csv("data/bgg_GameItem.csv")

#print(info_juegos.dtypes)
original_info_juegos = info_juegos.copy()
new_info_juegos = info_juegos[["artist", "designer","mechanic", "category", "game_type", "family", "publisher"]]
#info_juegos

new_info_juegos.to_csv("data/new_info_juegos.csv")
new_info_juegos
# Out:
#              artist              designer                            mechanic  \
# 0        12517,4959                     1       2916,2080,2012,2072,2040,2020
# 1             12424                  8384                                2009
# 2             11883                     2       2080,2040,2026,2846,2004,2002
# 3              2277                  8008                 2001,2080,2012,2004
# 4       12658,18317                     4  2040,2910,2900,2940,2005,2002,2874
# ...             ...                   ...                                 ...
# 113899          NaN      62310,62311,6736                                2017
# 113900          NaN  154290,123339,154289                      2073,2038,2019
# 113901       113637                 39436                      2011,2081,2007
# 113902        45292                  8347                      2040,2004,2819
# 113903        81537                 81537            2857,3002,2875,2040,2047
#
# ...

# %% [markdown]
# **b) (0.2 pts)** ¿Cuánto espacio en disco ocupa este DataFrame? ¿Cuánto espacio en disco ocupan los documentos CSV separados? ¿A qué se debe esta diferencia? Comente.

# %% [markdown]
# El nuevo archivo '''new_info_juegos.csv''' ocupa 6.909 KB. Todos los demás en total ocupan 40.1 MB, que van desde 1 KB a 783 KB. Esta diferencia es porque mientras mas datos tiene un archivo csv, más pesa ese archivo.

# %% [markdown]
# ### 3.2 Juegos publicados anualmente (1.5 puntos)
#
#
# **a) (0.5 pts)** Limpie los datos para dejar solo aquellos que tienen valores válidos de año de publicación. Luego responda: ¿cuál es el rango de años con el que estamos trabajando? ¿Tienen sentido estos años?

# %%
info_juegos = info_juegos[info_juegos["year"]<=2025]
info_juegos = info_juegos.sort_values("year")
info_juegos
 
# Estamos trabajando con un rango de años de 5525 años, lo que tiene sentido, porque por ejemplo las "bolitas" o "canicas" que en ingles son "marbles" sale en la tabla,
# y claramente es muy posible que la humanidad en esos años jueguen juegos de ese estilo que se han mantenido hasta el dia de hoy, con algo jugaban en la antiguedad.
# Out:
#         bgg_id                 name    year game_type designer  \
# 2060      2399                Senet -3500.0      4666        3
# 3593      4148                Mehen -3000.0      4666        3
# 4815      5546              Marbles -3000.0      4665        3
# 20170    23211           20 Squares -3000.0       NaN        3
# 10284    11726         Knucklebones -3000.0       NaN        3
# ...        ...                  ...     ...       ...      ...
# 113650  387912           Thistleden  2025.0       NaN   101831
# 112367  379925    Studium | No Exit  2025.0       NaN      NaN
# 113355  385960      Era of Atlantis  2025.0       NaN    57620
# 113781  389094  Mercurial: Alchemia  2025.0       NaN    85703
# 113685  388334  Defend Megatropolis  2025.0       NaN   153064
#
#                          artist  \
# 2060    64922,128192,7628,79195
# 3593                       7628
# 4815                        NaN
# 20170                       NaN
# 10284                       NaN
# ...

# %% [markdown]
# **b) (0.5 pts)** Seleccione solamente los juegos entre los años 1980 y 2025. Luego grafique la cantidad de juegos publicados por año. ¿Cómo es esta tendencia? Comente.

# %%
info_juegos = info_juegos[(info_juegos["year"]<=2025) & (info_juegos["year"]>=1980)]

info_juegos

info_juegos.groupby("year")["name"].count()

plt.plot(info_juegos.groupby("year")["name"].count())

# En el grafico podemos apreciar que justo antes de la pandemia fue el auge de los juegos de mesa, pero despues de ella se desplomo casi verticalmente.

# %% [markdown]
# **c) (0.5 pts)** ¿Entre qué años hubo un mayor aumento de publicación de juegos de mesa según los registros de BGG?

# %%
anos = info_juegos.groupby("year")["name"].count()
diferencia_anos = 0
ano_max = 0
for ano in range(1, len(anos.values)):
    dif = abs(anos.values[ano] - anos.values[ano - 1])
    if dif > diferencia_anos:
        diferencia_anos = dif
        ano_max = 1980 + ano

print(f"El mayor aumento de juegos de mesa fue entre {ano_max - 1} y {ano_max}")
# Out:
# El mayor aumento de juegos de mesa fue entre 2023 y 2024

# %% [markdown]
# ### 3.3 Análisis de duración y complejidad (1.5 puntos)
#
# Si bien hay muchas posibles características que podemos explorar para los juegos de mesa, esta vez nos centraremos en el tiempo de juego y la complejidad. En esta sección queremos comprender si se ha modificado notablemente la duración promedio y la percepción de complejidad de los juegos de mesa a través de los años.

# %% [markdown]
# **a) (0.3 pts)** Inspecciones y filtre los datos que tengan valores válidos para: tiempo mínimo de juego, tiempo máximo de juego y complejidad. En el caso de que existan "outliers", puede descartarlos, cosiderando un rango razonable para las variables anteriores. Justifique su desición.

# %%
analisis_info_juegos = original_info_juegos.copy()[["min_time", "max_time", "complexity"]]

nuevo_analisis = analisis_info_juegos.sort_values("min_time")[((analisis_info_juegos["min_time"]<=1200) | analisis_info_juegos["min_time"].isna())]
# Escogi este rango de tiempo minimo, ya que entre 0 y 1200 no suben de a mas de 100, despues de ese numero empiezan a subir de una cantidad absurda
# Para evitar que saque aquellos que sean nan pero son utiles para los otros parametros, use .isna(), sacado del link https://stackoverflow.com/questions/47440077/how-to-check-if-particular-value-in-cell-is-nan-in-pandas-dataframe

# Descarto aquellos que tienen 3 NaN, tambien recurri a la documentacion misma de pandas esta vez https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
nuevo_analisis = nuevo_analisis.dropna(how="all")

# Bajo la misma logica hare el tiempo max
nuevo_analisis = nuevo_analisis.sort_values("max_time")[((nuevo_analisis["max_time"]<=1200) | nuevo_analisis["min_time"].isna())]
nuevo_analisis

# Descartare aquellos que el tiempo max sea mayor al minimo
nuevo_analisis = nuevo_analisis.sort_values("max_time")[((nuevo_analisis["max_time"]>=nuevo_analisis["min_time"]) | nuevo_analisis["min_time"].isna() | nuevo_analisis["max_time"].isna())]
nuevo_analisis

# En complejidad hay dos grandes saltos, salta de 500 a mil,y despues de 5 mil a 10 mil dejando un rango amplio entre medio, pero despues sigue hasta cerca de los 50 mil, por ende no creo que alguno se pueda considerar outlier, porque se divide como en tres partes casi iguales
# Pero si lo ordenare por complejidad simplemente porque con tiempo hay dos parametros
nuevo_analisis = nuevo_analisis.sort_values("complexity")
nuevo_analisis
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_30716\3530086845.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nuevo_analisis = analisis_info_juegos.sort_values("min_time")[((analisis_info_juegos["min_time"]<=1200) | analisis_info_juegos["min_time"].isna())]
# C:\Users\crist\AppData\Local\Temp\ipykernel_30716\3530086845.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nuevo_analisis = nuevo_analisis.sort_values("max_time")[((nuevo_analisis["max_time"]<=1200) | nuevo_analisis["min_time"].isna())]
#         min_time  max_time  complexity
# 91595       15.0      40.0         1.0
# 109684       1.0       1.0         1.0
# 113518       NaN       NaN         1.0
# 12974        1.0       1.0         1.0
# 18213        1.0       1.0         1.0
# ...          ...       ...         ...
# 60688     1200.0    1200.0         NaN
# 93391      120.0    1200.0         NaN
# 81829     1200.0    1200.0         NaN
# ...

# %% [markdown]
# **b) (0.2 pts)** Veremos ahora si ha cambiado la duración promedio de los juegos de mesa en nuestro rango de años seleccionado. Primero, cree una nueva columna `avg_time` en el dataset con la duración promedio supuesta para cada juego.

# %%
avg_time = (nuevo_analisis["min_time"] + nuevo_analisis["max_time"]) / 2
avg_time

#nueva_info_juegos = original_info_juegos.copy()
nuevo_analisis["avg_time"] = avg_time
nuevo_analisis
# Out:
#         min_time  max_time  complexity  avg_time
# 91595       15.0      40.0         1.0      27.5
# 109684       1.0       1.0         1.0       1.0
# 113518       NaN       NaN         1.0       NaN
# 12974        1.0       1.0         1.0       1.0
# 18213        1.0       1.0         1.0       1.0
# ...          ...       ...         ...       ...
# 60688     1200.0    1200.0         NaN    1200.0
# 93391      120.0    1200.0         NaN     660.0
# 81829     1200.0    1200.0         NaN    1200.0
# 60687     1200.0    1200.0         NaN    1200.0
# 71440      120.0    1200.0         NaN     660.0
#
# [95927 rows x 4 columns]

# %% [markdown]
# **c) (0.5 pts)** Grafique la duración promedio de juegos al año entre 1980 y 2025. ¿Existe alguna tendencia? Asegúrese de colocar las unidades correspondientes en sus ejes si es necesario. Comente sus resultados.

# %%
nuevo_analisis_anos_restringidos = original_info_juegos.copy()[["min_time", "max_time", "year"]]
nuevo_analisis_anos_restringidos = nuevo_analisis_anos_restringidos.sort_values("year")[(nuevo_analisis_anos_restringidos["year"]<=2025) & (nuevo_analisis_anos_restringidos["year"]>=1980)]
nuevo_analisis_anos_restringidos
avg_time = (nuevo_analisis_anos_restringidos["min_time"] + nuevo_analisis_anos_restringidos["max_time"]) / 2
avg_time

#nueva_info_juegos = original_info_juegos.copy()
nuevo_analisis_anos_restringidos["avg_time"] = avg_time




nuevo_analisis_anos_restringidos = nuevo_analisis_anos_restringidos.sort_values("min_time")[((nuevo_analisis_anos_restringidos["min_time"]<=1200) | nuevo_analisis_anos_restringidos["min_time"].isna())]
nuevo_analisis_anos_restringidos.dropna(how="all")
nuevo_analisis_anos_restringidos = nuevo_analisis_anos_restringidos.sort_values("max_time")[((nuevo_analisis_anos_restringidos["max_time"]<=1200) | nuevo_analisis_anos_restringidos["min_time"].isna())]
nuevo_analisis_anos_restringidos = nuevo_analisis_anos_restringidos.sort_values("max_time")[((nuevo_analisis_anos_restringidos["max_time"]>=nuevo_analisis_anos_restringidos["min_time"]) | nuevo_analisis_anos_restringidos["min_time"].isna() | nuevo_analisis_anos_restringidos["max_time"].isna())]
nuevo_analisis_anos_restringidos = nuevo_analisis_anos_restringidos.sort_values("avg_time")[nuevo_analisis_anos_restringidos["avg_time"]>0]
grafico_analisis = nuevo_analisis_anos_restringidos.groupby("year")["avg_time"].mean()



grafico_analisis.plot()

# La tendencia esta clara, entre 1980 al 2020, la duracion de los juegos fue bajando cada vez mas, hasta la pandemia, que nuevamente, como en la creacion de juegos de mesa, esta influyo y subio enormemente el promedio de duracion de los juegos de mesa
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_30716\3597145633.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nuevo_analisis_anos_restringidos = nuevo_analisis_anos_restringidos.sort_values("year")[(nuevo_analisis_anos_restringidos["year"]<=2025) & (nuevo_analisis_anos_restringidos["year"]>=1980)]
# C:\Users\crist\AppData\Local\Temp\ipykernel_30716\3597145633.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nuevo_analisis_anos_restringidos = nuevo_analisis_anos_restringidos.sort_values("min_time")[((nuevo_analisis_anos_restringidos["min_time"]<=1200) | nuevo_analisis_anos_restringidos["min_time"].isna())]
# C:\Users\crist\AppData\Local\Temp\ipykernel_30716\3597145633.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %% [markdown]
# **d) (0.5 pts)** Nos interesa saber si los juegos de mesa recientes son más complejos que aquellos publicados antes de los 2000. BoardGameGeek permite evaluar la complejidad (o "weight") de un juego en una escala de 1 a 5, siendo 1 un juego "liviano" o fácil de entender, y 5 un juego "pesado" o complejo. Primero, seleccione los juegos que han sido evaluados por al menos 100 usuarios. Luego grafique la complejidad promedio de los juegos según año. Responda: ¿ha cambiado la percepción de complejidad entre juegos entre 1980 y la actualidad?

# %%
nuevo_analisis = original_info_juegos.copy()[["num_votes", "complexity", "year"]]

nuevo_analisis = nuevo_analisis.sort_values("complexity")[((nuevo_analisis["num_votes"]>=100) & (nuevo_analisis["year"]>=1980) & (nuevo_analisis["year"]<=2025))]
nuevo_analisis

grafico_analisis = nuevo_analisis.groupby("year")["complexity"].mean()
grafico_analisis.plot()

# A principio del siglo eran mas faciles, pero nuevamente gracias a la pandemia, estos pasaron de ser la mitad de dificiles del ano pasado a ser de casi el doble
# Out:
# C:\Users\crist\AppData\Local\Temp\ipykernel_30716\3523748961.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nuevo_analisis = nuevo_analisis.sort_values("complexity")[((nuevo_analisis["num_votes"]>=100) & (nuevo_analisis["year"]>=1980) & (nuevo_analisis["year"]<=2025))]
# <Axes: xlabel='year'>

# %% [markdown]
# ### 3.4 Análisis de categorías comunes (2 puntos)
#
# Existe una gran diversidad de categorías de juegos de mesa. Ahora nos concentraremos en un grupo específico de ellas, con el fin de analizar cómo a cambiado la cantidad de juegos de estas clases desde 1980 hasta hoy.
#
# **a) (0.7 pts)** ¿Cuáles son las 5 categorías más comunes en los juegos del dataset? Muestre la cantidad de juegos que hay de cada una. Puede graficar estos valores, o bien, entregar un DataFrame con sus valores.

# %%
nuevo_analisis = original_info_juegos.copy()[["category", "year"]]
nuevo_analisis = nuevo_analisis[((nuevo_analisis["year"]>=1980) & (nuevo_analisis["year"]<=2025))]
lista_categorias = []
for categoria in nuevo_analisis["category"]:
    categoria_separada = str(categoria).split(",")
    for categoria_separar in categoria_separada:
        lista_categorias.append(categoria_separar)

categorias_contadas = {}

for categoria in lista_categorias:
    if categoria in categorias_contadas:
        categorias_contadas[categoria] +=1
    else:
        categorias_contadas[categoria] = 1


categorias_contadas = sorted(categorias_contadas.items(), key=lambda x: x[1], reverse=True)
categorias_contadas
top_5_categorias = []
for top_5 in range(5):
    top_5_categorias.append(categorias_contadas[top_5][0])
    print(categorias_contadas[top_5])
# Out:
# ('1002', 25900)
# ('1019', 12502)
# ('1041', 11706)
# ('1030', 9574)
# ('1010', 8358)

# %% [markdown]
# **b) (0.3 pts)** Para cada una de estas 5 categorías, cree un DataFrame que contenga la cantidad de juegos en el dataset según año. Luego junte estos DataFrames en uno solo con los atributos de "Año", "Categoría" y "Cantidad".

# %%
"""
para esta parte, saque iloc, que me permite recorrer cada fila, gracias a chatGPT


mi prompt fue el siguiente:

en pandas en un dataframe, como puedo recorrer con un for una columna y agregar un dato de otra columna pero la misma fila a una lista


y su respuesta fue (use unicamnte una linea de lo que me dio chatGPT, pero de igual forma preferi citarlo completo para evitar falta a la integridad academica):

Eso es más simple que levantarse un lunes: en Pandas, cuando recorres una columna con un `for`, el índice que usas te da acceso a la **misma fila** en las demás columnas.

Ejemplo directo:

```python
import pandas as pd

# DataFrame de ejemplo
df = pd.DataFrame({
    "col1": [10, 20, 30],
    "col2": ["a", "b", "c"]
})

lista = []

for i, valor in enumerate(df["col1"]):  
    lista.append(df["col2"].iloc[i])  # misma fila en col2

print(lista)  # ['a', 'b', 'c']
```

---

Otra forma (más "panda way") es usar `zip` y ahorrarte el loop cavernícola:

```python
lista = [c2 for c1, c2 in zip(df["col1"], df["col2"])]
```

O si solo te interesa una columna en función de otra, siempre está el clásico:

```python
lista = df["col2"].tolist()
```

---

👉 Pregunta: ¿quieres **recorrer con condición** (ej: si `col1 > 15` entonces agregar `col2`), o simplemente copiar la otra columna a la lista sin más?


"""



nuevo_analisis = original_info_juegos.copy()[["category", "year"]]
nuevo_analisis = nuevo_analisis[((nuevo_analisis["year"]>=1980) & (nuevo_analisis["year"]<=2025))]
lista_categorias = {}

for fila in range(len(nuevo_analisis)):
    categorias_fila = str(nuevo_analisis["category"].iloc[fila]).split(",")
    ano = int(nuevo_analisis["year"].iloc[fila])
    if ano not in lista_categorias:
         lista_categorias[ano] = {}
    for categoria in categorias_fila:
            if categoria in lista_categorias[ano]:
                lista_categorias[ano][categoria] += 1
            elif categoria in top_5_categorias:
                    lista_categorias[ano][categoria] = 1



dataframe_final = pd.DataFrame(lista_categorias)
dataframe_final = dataframe_final[sorted(dataframe_final.columns)]
grafico_dataframe = dataframe_final.copy()
dataframe_final["total"] = dataframe_final.sum(axis=1)

dataframe_final.sort_values("total")
# Out:
#       1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  2017  \
# 1010    33    40    30    41    38    42    41    38    23    46  ...   469
# 1030     8    11    11    16    32    61    53    62    84    74  ...   589
# 1041    75    76    60   106   122   108   121   111   145   145  ...   432
# 1019   170   181   140   177   133   131   156   120   108   108  ...   506
# 1002    43    52    58    86    70    64    66    78    85    89  ...  1667
#
#       2018  2019  2020  2021  2022  2023  2024  2025    total
# 1010   590   586   542   555   567   412    67   3.0   8358.0
# 1030   671   718   644   572   544   197     8   NaN   9574.0
# 1041   442   485   452   506   338   100     4   NaN  11706.0
# 1019   542   597   604   513   485   328    37   1.0  12502.0
# 1002  1612  1719  1600  1684  1612   889    58   5.0  25900.0
#
# [5 rows x 47 columns]

# %% [markdown]
# **c) (1 pto)** Grafique, en un solo gráfico y con distintos colores, la cantidad de juegos por año según categoría. Preocúpese de ponerle etiquetas al gráfico para identificar cada categoría y una leyenda donde se muestre cada una. Comente: ¿ha habido un cambio entre los juegos más comunes en los años 80 y hoy?

# %%
for fila in range(len(grafico_dataframe)):
    plt.plot(np.arange(len(grafico_dataframe.columns)), grafico_dataframe.iloc[fila], label=f"Categoria de la {fila + 1} fila del dataframe")

plt.xticks(np.arange(len(grafico_dataframe.columns)), grafico_dataframe.columns, rotation=90)
plt.xlabel("Anos")
plt.ylabel("Cantidad de juegos")
plt.legend()

# Exactamente igual que los demas graficos, empiezan a aumentar significativamente, hasta llegar a la pandemia, dondee caen en picada


grafico_dataframe
# Out:
#       1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  2016  \
# 1019   170   181   140   177   133   131   156   120   108   108  ...   539
# 1010    33    40    30    41    38    42    41    38    23    46  ...   462
# 1002    43    52    58    86    70    64    66    78    85    89  ...  1545
# 1030     8    11    11    16    32    61    53    62    84    74  ...   592
# 1041    75    76    60   106   122   108   121   111   145   145  ...   444
#
#       2017  2018  2019  2020  2021  2022  2023  2024  2025
# 1019   506   542   597   604   513   485   328    37   1.0
# 1010   469   590   586   542   555   567   412    67   3.0
# 1002  1667  1612  1719  1600  1684  1612   889    58   5.0
# 1030   589   671   718   644   572   544   197     8   NaN
# 1041   432   442   485   452   506   338   100     4   NaN
#
# [5 rows x 46 columns]

# %% [markdown]
# ### 3.5 Análisis Crítico (Bono +0.5 puntos)
#
# ¿Qué limitaciones o problemas encontraste en los datos?

# %%
""" 

En estos datos hay unos pequenos problemas, principalmente dos, el gran rango entree los anos de publicacion, ya que cuenta los juegos de mesa de todos los anos,
incluyendo aquellos de hace mas de 3000 anos, dificultando el analisis historico de los juegos, y tambien esta el problema de la pandemia, ya que no se sabe si todos los graficos 
tienen un bajon al comienzo de ella porque efectivamente asi fue, o porque hubo un problema con los datos, ya que son cambios drasticos, de cualquier forma eso nos 
limita al momento de querer hacer un analizis, porque terminan siendo outliers aquellos datos post pandemia.

"""
